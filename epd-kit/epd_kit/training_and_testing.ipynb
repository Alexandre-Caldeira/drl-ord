# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt

with open('c_states_dict_v4.pkl', 'rb') as f:
    c_states = pickle.load(f)

    
# with open('c_states_dict_acer_2.pkl', 'rb') as f:
#     c_states_test = pickle.load(f)

# with open('states_dict_v2.pkl', 'rb') as f:
    # states = pickle.load(f)

print(len(c_states))
print(c_states[5].shape)
# Out:
# 5
# (2500, 18, 7, 120)

# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np

class TEST_FrequencyDetectionEnv(gym.Env):
    """Custom Environment for Frequency Objective Response Detection that follows gymnasium interface"""

    def __init__(self, data):
        super(TEST_FrequencyDetectionEnv, self).__init__()

        self.data = data
        self.episodes = data.shape[0]-1
        self.frequencies = data.shape[1]-1
        self.measures = data.shape[2]
        self.windows = data.shape[3]-1
        self.current_episode = 0
        self.current_window = 2
        self.current_frequency = 0

        # Action space: 0 (no detection) or 1 (detection)
        self.action_space = spaces.Discrete(2)

        # Observation space: 5 measures for each of the 4 frequencies (1 focus + 3 noise)
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(4*self.measures,), dtype=np.float32)
        # self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(self.measures,), dtype=np.float32)

        # Initialize the internal state
        self.state = None
        self.false_positives = 0
        self.true_positives = 0
        self.fp_rate = 0
        self.tp_rate = 0   
        self.tpr_hist = []
        self.fpr_hist = []     

    def reset(self, seed=None, options=None):
        """Resets the environment to an initial state and returns the initial observation."""
        super().reset(seed=seed)
        
        if  self.current_episode< self.episodes:
            self.current_episode +=1
        else:
            self.current_episode = np.random.randint(0, self.episodes)

        self.current_window = 2
        self.current_frequency = 0
        self.false_positives = 0
        self.true_positives = 0
        self.fp_rate = 0
        self.tp_rate = 0        
         
        self.tpr_hist = []
        self.fpr_hist = []
        
        # Initialize the state
        self.state = self._get_state(self.current_frequency, self.current_window)
        return self.state, {}

    def _get_state(self, frequency, window, episode= 0):
        """Helper function to get the state at a given frequency and window."""
         
        if episode != 0:
            self.current_episode = episode
         
        # print(frequency)
        focus_measure = self.data[self.current_episode, frequency, :, window]
         
        # Select 3 random noise frequencies, excluding the current focus frequency
        noise_indices = np.setdiff1d(np.arange(9, 17), frequency - 9 if frequency >= 9 else [])
        noise_frequencies = np.random.choice(noise_indices, 3, replace=False)
        noise_measures = [self.data[self.current_episode, nf, :, window] for nf in noise_frequencies]
         
        measures = np.concatenate(([focus_measure], noise_measures), axis=0).flatten()
       
        return np.array(measures, dtype=np.float32)

    def step(self, action, episode = -1):
        """Executes one time step within the environment."""
        # Returns:
        # tuple (observation, reward, terminated, truncated, info).
        # Return type:
        # Tuple[Tuple | Dict[str, Any] | ndarray | int, float, bool, bool, Dict]

        if episode != -1:
            self.current_episode = episode

        reward = 0
        fp_des = 0.05

        should_detect = self.current_frequency <= 8
        if action == 1:
            if should_detect:
                self.true_positives += 1
            else:
                self.false_positives += 1

        self.current_frequency += 1
        window_done = self.current_frequency >= self.frequencies
        epsiode_terminated = self.current_window >= self.windows
        info = {'tp_rate':np.nan,'fp_rate':np.nan}
        if window_done:
            self.state = self._get_state(self.current_frequency-1, self.current_window)

            should_detect = self.current_frequency <= 8
            tp = 0; fp = 0; fn =0; tn = 0
            if action == 1:
                if should_detect:
                    tp = 0
                else:
                    fp = 1
            else:
                if should_detect:
                    fn = 0
                else:
                    tn = 1

            reward = tp-fp-fn+tn


            self.tp_rate = 100*self.true_positives / (self.frequencies//2+1)
            self.fp_rate = 100*self.false_positives / (self.frequencies//2+1)

            self.tpr_hist.append(self.tp_rate)
            self.fpr_hist.append(self.fp_rate)

            # print(f'Window: {self.current_window}, Should Detect Frequency: {should_detect}({self.current_frequency}), Action: {action},,TP: {self.true_positives}, FP: {self.false_positives} ')
            
            if not(epsiode_terminated):
                self.current_window += 1
                self.current_frequency = 0
                self.true_positives = 0
                self.false_positives = 0
                    
        if epsiode_terminated:
            self.state = self._get_state(self.current_frequency, self.current_window)
            current_ep_prog =100 # np.round(100*self.current_window/self.windows,2) #self.state[3]

            self.tp_rate = 100*self.true_positives / (self.current_frequency+1)
            self.fp_rate = 100*self.false_positives / (self.current_frequency+1)

            should_detect = self.current_frequency <= 8
            tp = 0; fp = 0; fn =0; tn = 0
            if action == 1:
                if should_detect:
                    tp = 0
                else:
                    fp = 1
            else:
                if should_detect:
                    fn = 0
                else:
                    tn = 1

            reward = tp-fp-fn+tn
           
            truncated = False

            # print(f'Episode: {self.current_episode},TP: {np.round(self.tp_rate,2)}, FP: {np.round(self.fp_rate,2)}, R: {reward}')            
            # print(f'TPR_h: {np.round(np.mean(self.tpr_hist),2)}, FPR_h: {np.round(np.mean(self.fpr_hist),2)}')
            info = {'tp_rate':np.round(np.mean(self.tpr_hist),2),'fp_rate':np.round(np.mean(self.fpr_hist),2)}

            self.tpr_hist = []
            self.fpr_hist = [] 
            self.current_window = 2
            self.current_frequency = 0
            self.true_positives = 0
            self.false_positives = 0

        else:
            self.state = self._get_state(self.current_frequency, self.current_window)

            should_detect = self.current_frequency <= 8
            tp = 0; fp = 0; fn =0; tn = 0
            if action == 1:
                if should_detect:
                    tp = 0
                else:
                    fp = 1
            else:
                if should_detect:
                    fn = 0
                else:
                    tn = 1

            reward = tp-fp-fn+tn

            truncated = False

        reward = tp-fp-fn+tn

        return self.state, reward, epsiode_terminated, truncated, info

    def render(self, mode='human'):
        """Render the environment for visualization purposes."""
        print(f'Window: {self.current_window}, Frequency: {self.current_frequency},TP: {self.tp_rate}, FP: {self.fp_rate}')

    def close(self):
        """Clean up any resources used by the environment."""
        pass

# %%
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
from stable_baselines3 import PPO, DQN
from stable_baselines3.common.vec_env import DummyVecEnv
from gymnasium import spaces

# Custom Environment definition (from your provided code)
class FrequencyDetectionEnv(gym.Env):
    """Custom Environment for Frequency Objective Response Detection that follows gymnasium interface"""

    def __init__(self, data):
        super(FrequencyDetectionEnv, self).__init__()

        self.data = data
        self.episodes = data.shape[0]-1
        self.frequencies = data.shape[1]-1
        self.measures = data.shape[2]
        self.windows = data.shape[3]-1
        self.current_episode = 0
        self.current_window = 2
        self.current_frequency = 0

        # Action space: 0 (no detection) or 1 (detection)
        self.action_space = spaces.Discrete(2)

        # Observation space: 5 measures for each of the 4 frequencies (1 focus + 3 noise)
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(4*self.measures,), dtype=np.float32)
        # self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(self.measures,), dtype=np.float32)

        # Initialize the internal state
        self.state = None
        self.false_positives = 0
        self.true_positives = 0
        self.fp_rate = 0
        self.tp_rate = 0   
        self.tpr_hist = []
        self.fpr_hist = []     

    def reset(self, seed=None, options=None):
        """Resets the environment to an initial state and returns the initial observation."""
        super().reset(seed=seed)
        
        if  self.current_episode< self.episodes:
            self.current_episode +=1
        else:
            self.current_episode = np.random.randint(0, self.episodes)

        self.current_window = 2
        self.current_frequency = 0
        self.false_positives = 0
        self.true_positives = 0
        self.fp_rate = 0
        self.tp_rate = 0        
         
        self.tpr_hist = []
        self.fpr_hist = []
        
        # Initialize the state
        self.state = self._get_state(self.current_frequency, self.current_window)
        return self.state, {}

    def _get_state(self, frequency, window, episode= 0):
        """Helper function to get the state at a given frequency and window."""
         
        if episode != 0:
            self.current_episode = episode
         
        # print(frequency)
        focus_measure = self.data[self.current_episode, frequency, :, window]
         
        # Select 3 random noise frequencies, excluding the current focus frequency
        noise_indices = np.setdiff1d(np.arange(9, 17), frequency - 9 if frequency >= 9 else [])
        noise_frequencies = np.random.choice(noise_indices, 3, replace=False)
        noise_measures = [self.data[self.current_episode, nf, :, window] for nf in noise_frequencies]
         
        measures = np.concatenate(([focus_measure], noise_measures), axis=0).flatten()
        # measures = self.data[self.current_episode, frequency, :, window]


        # noise_indices = np.setdiff1d(np.arange(9, 17), frequency - 9 if frequency >= 9 else [])
        # noise_frequencies = np.random.choice(noise_indices, 3, replace=False)
        # past_noise_measures = [self.data[self.current_episode, nf, :, window-1] for nf in noise_frequencies]

        # past_focus_measure = self.data[self.current_episode, frequency, :, window-1]
        # past_measures = np.concatenate(([past_focus_measure], past_noise_measures), axis=0).flatten()

        # measures = np.concatenate((measures, past_measures), axis=0).flatten()
        return np.array(measures, dtype=np.float32)

    def step(self, action, episode = -1):
        """Executes one time step within the environment."""
        # Returns:
        # tuple (observation, reward, terminated, truncated, info).
        # Return type:
        # Tuple[Tuple | Dict[str, Any] | ndarray | int, float, bool, bool, Dict]

        if episode != -1:
            self.current_episode = episode

        reward = 0
        kp_fp = 1.1
        fp_des = 0.05

        should_detect = self.current_frequency <= 8
        if action == 1:
            if should_detect:
                self.true_positives += 1
            else:
                self.false_positives += 1

        self.current_frequency += 1
        window_done = self.current_frequency >= self.frequencies
        epsiode_terminated = self.current_window >= self.windows
        info = {'tp_rate':np.nan,'fp_rate':np.nan}
        if window_done:
            self.state = self._get_state(self.current_frequency-1, self.current_window)

            current_ep_prog = 100 #np.round(100*self.current_window/self.windows,2) #self.state[3]
            
            fp_des = 0.05
            self.tp_rate = 100*self.true_positives / (self.frequencies//2+1)
            self.fp_rate = 100*self.false_positives / (self.frequencies//2+1)
                
            reward = +( -(((100-fp_des)**2)/100 +(fp_des**2)/-100) +((self.fp_rate)**2)/(-100)+ ((self.tp_rate)**2)/(100) )*current_ep_prog/100
            
            self.tpr_hist.append(self.tp_rate)
            self.fpr_hist.append(self.fp_rate)

            # should_detect = self.current_frequency <= 8
            # tp = 0; fp = 0; fn =0; tn = 0
            # fp = self.fp_rate
            # if (action == 1) and (fp>fp_des*100):
            #     if should_detect:
            #         tp = 0
            #     else:
            #         fp = -50
            # else:
            #     if should_detect:
            #         fn = -50
            #     else:
            #         tn = 0
            
            # print(f'Window: {self.current_window}, Should Detect Frequency: {should_detect}({self.current_frequency}), Action: {action},,TP: {self.true_positives}, FP: {self.false_positives} ')
            
            if not(epsiode_terminated):
                self.current_window += 1
                self.current_frequency = 0
                self.true_positives = 0
                self.false_positives = 0
                    
        if epsiode_terminated:
            self.state = self._get_state(self.current_frequency, self.current_window)
            current_ep_prog =100 # np.round(100*self.current_window/self.windows,2) #self.state[3]

            self.tp_rate = 100*self.true_positives / (self.current_frequency+1)
            self.fp_rate = 100*self.false_positives / (self.current_frequency+1)

            reward = +( -(((100-fp_des)**2)/100+(fp_des**2)/-100)
                    +(kp_fp*(np.round(np.mean(self.fpr_hist),4))**2)/(-100)
                    +((np.round(np.mean(self.tpr_hist),4))**2)/(100))*current_ep_prog/100
           
            truncated = False

            # if (action == 1) and (self.fp_rate>fp_des*100):
            #     if should_detect:
            #         pass
            #     else:
            #         reward = -200
            # else:
            #     if should_detect:
            #         reward = -200
            #     else:
            #         pass

            # self.tpr_hist.append(self.tp_rate)
            # self.fpr_hist.append(self.fp_rate)

            print(f'Episode: {self.current_episode},TP: {np.round(self.tp_rate,2)}, FP: {np.round(self.fp_rate,2)}, R: {reward}')            
            print(f'TPR_h: {np.round(np.mean(self.tpr_hist),2)}, FPR_h: {np.round(np.mean(self.fpr_hist),2)}')
            info = {'tp_rate':np.round(np.mean(self.tpr_hist),2),'fp_rate':np.round(np.mean(self.fpr_hist),2)}

            self.tpr_hist = []
            self.fpr_hist = [] 
            self.current_window = 2
            self.current_frequency = 0
            self.true_positives = 0
            self.false_positives = 0

        else:
            self.state = self._get_state(self.current_frequency, self.current_window)

            should_detect = self.current_frequency <= 8
            tp = 0; fp = 0; fn =0; tn = 0
            if action == 1:
                if should_detect:
                    tp = 1
                else:
                    fp = 1
            else:
                if should_detect:
                    fn = 1
                else:
                    tn = 1

            reward = tp-kp_fp*fp-fn+tn

            truncated = False

        # if (action == 1):
        #     if should_detect:
        #         # TP
        #         reward = 1
        #     else:
        #         # FP
        #         reward = -2
        # else:
        #     if should_detect:
        #         # FN
        #         reward = -1
        #     else:
        #         # TN
        #         reward = 0

        # if self.fp_rate>fp_des*100:
        #     reward = 10*reward

        return self.state, reward, epsiode_terminated, truncated, info
    def render(self, mode='human'):
        """Render the environment for visualization purposes."""
        print(f'Window: {self.current_window}, Frequency: {self.current_frequency},TP: {self.tp_rate}, FP: {self.fp_rate}')

    def close(self):
        """Clean up any resources used by the environment."""
        pass

# %%
# Assuming the data variable is already defined and loaded with the appropriate shape
# data = np.load('your_data.npy')  # Load your data here
snr = -5
data = c_states[snr]
# env = DummyVecEnv([lambda: FrequencyDetectionEnv(data)])
env = FrequencyDetectionEnv(data)
# Train PPO model
model_ppo = PPO('MlpPolicy', env, verbose=1)
model_ppo.learn(total_timesteps=120*17*500)
model_ppo.save('ppo_snr-5.zip')
env.reset()

# Train DQN model
model_dqn = DQN('MlpPolicy', env, verbose=1)
model_dqn.learn(total_timesteps=120*17*500)
model_dqn.save('dqn_snr-5.zip')
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Episode: 1,TP: 0.0, FP: 0.0, R: -95.88721532971
# TPR_h: 49.0, FPR_h: 42.64
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.99e+03 |
# |    ep_rew_mean     | -120     |
# | time/              |          |
# |    fps             | 1318     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode: 2,TP: 0.0, FP: 0.0, R: -97.32444012859
# TPR_h: 55.46, FPR_h: 50.62
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | -161        |
# | time/                   |             |
# |    fps                  | 787         |
# |    iterations           | 2           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.011579951 |
# |    clip_fraction        | 0.0634      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.684      |
# |    explained_variance   | 0.00727     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.49        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00726    |
# |    value_loss           | 46.6        |
# -----------------------------------------
# Episode: 3,TP: 0.0, FP: 0.0, R: -97.6223196565
# TPR_h: 52.99, FPR_h: 48.43
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.99e+03     |
# |    ep_rew_mean          | -161         |
# | time/                   |              |
# |    fps                  | 699          |
# |    iterations           | 3            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0071299253 |
# |    clip_fraction        | 0.058        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.686       |
# |    explained_variance   | 0.0512       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 35.9         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00868     |
# |    value_loss           | 45.8         |
# ------------------------------------------
# Episode: 4,TP: 50.0, FP: 0.0, R: -94.65110460626002
# TPR_h: 57.45, FPR_h: 50.24
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | -149        |
# | time/                   |             |
# |    fps                  | 676         |
# |    iterations           | 4           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008083664 |
# |    clip_fraction        | 0.06        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.671      |
# |    explained_variance   | 0.0483      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.4        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00637    |
# |    value_loss           | 43.3        |
# -----------------------------------------
# Episode: 5,TP: 0.0, FP: 0.0, R: -91.66511716801001
# TPR_h: 58.69, FPR_h: 48.81
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.99e+03     |
# |    ep_rew_mean          | -116         |
# | time/                   |              |
# |    fps                  | 648          |
# |    iterations           | 5            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0073844288 |
# |    clip_fraction        | 0.086        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.651       |
# |    explained_variance   | 0.0865       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 24.3         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0125      |
# |    value_loss           | 42.8         |
# ------------------------------------------
# Episode: 6,TP: 50.0, FP: 0.0, R: -87.79554866033999
# TPR_h: 63.72, FPR_h: 50.9
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.99e+03     |
# |    ep_rew_mean          | -98.6        |
# | time/                   |              |
# |    fps                  | 614          |
# |    iterations           | 6            |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0065147234 |
# |    clip_fraction        | 0.038        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.651       |
# |    explained_variance   | 0.149        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.4         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00746     |
# |    value_loss           | 40.1         |
# ------------------------------------------
# Episode: 7,TP: 0.0, FP: 0.0, R: -88.67958812771002
# TPR_h: 58.78, FPR_h: 46.06
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | -80.2       |
# | time/                   |             |
# |    fps                  | 610         |
# |    iterations           | 7           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.009242674 |
# |    clip_fraction        | 0.0747      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.634      |
# |    explained_variance   | 0.165       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 43.9        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.012      |
# |    value_loss           | 37.2        |
# -----------------------------------------
# Episode: 8,TP: 0.0, FP: 0.0, R: -71.69056830121002
# TPR_h: 71.79, FPR_h: 46.06
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | -38.2       |
# | time/                   |             |
# |    fps                  | 610         |
# |    iterations           | 8           |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.008794316 |
# |    clip_fraction        | 0.0831      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.619      |
# |    explained_variance   | 0.154       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.2         |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00975    |
# |    value_loss           | 38.8        |
# -----------------------------------------
# Episode: 9,TP: 0.0, FP: 0.0, R: -88.69756829636002
# TPR_h: 54.99, FPR_h: 41.6
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.99e+03   |
# |    ep_rew_mean          | -37.2      |
# | time/                   |            |
# |    fps                  | 605        |
# |    iterations           | 9          |
# |    time_elapsed         | 30         |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.01474624 |
# |    clip_fraction        | 0.128      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.574     |
# |    explained_variance   | -0.00816   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 34.5       |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.016     |
# |    value_loss           | 30         |
# ----------------------------------------
# Episode: 10,TP: 0.0, FP: 0.0, R: -90.79937258273999
# TPR_h: 51.09, FPR_h: 39.32
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | -38.1       |
# | time/                   |             |
# |    fps                  | 602         |
# |    iterations           | 10          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.012927704 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.579      |
# |    explained_variance   | 0.106       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.96        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0123     |
# |    value_loss           | 39.2        |
# -----------------------------------------
# Episode: 11,TP: 50.0, FP: 0.0, R: -53.51230681826
# TPR_h: 79.11, FPR_h: 38.37
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.99e+03  |
# |    ep_rew_mean          | 7.42      |
# | time/                   |           |
# |    fps                  | 599       |
# |    iterations           | 11        |
# |    time_elapsed         | 37        |
# |    total_timesteps      | 22528     |
# | train/                  |           |
# |    approx_kl            | 0.0089131 |
# |    clip_fraction        | 0.0875    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.534    |
# |    explained_variance   | 0.103     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 4.3       |
# |    n_updates            | 100       |
# |    policy_gradient_loss | -0.00907  |
# |    value_loss           | 44.9      |
# ---------------------------------------
# Episode: 12,TP: 50.0, FP: 0.0, R: -54.45514961714
# TPR_h: 76.73, FPR_h: 34.95
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 54.9        |
# | time/                   |             |
# |    fps                  | 594         |
# |    iterations           | 12          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.010597596 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.503      |
# |    explained_variance   | 0.366       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.25        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0129     |
# |    value_loss           | 19.7        |
# -----------------------------------------
# Episode: 13,TP: 50.0, FP: 0.0, R: -55.25324911340001
# TPR_h: 75.88, FPR_h: 34.28
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.99e+03     |
# |    ep_rew_mean          | 85.3         |
# | time/                   |              |
# |    fps                  | 594          |
# |    iterations           | 13           |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0098525155 |
# |    clip_fraction        | 0.102        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.471       |
# |    explained_variance   | 0.178        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.4          |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00983     |
# |    value_loss           | 25.3         |
# ------------------------------------------
# Episode: 14,TP: 50.0, FP: 0.0, R: -46.69733295259
# TPR_h: 81.77, FPR_h: 35.23
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.99e+03  |
# |    ep_rew_mean          | 121       |
# | time/                   |           |
# |    fps                  | 596       |
# |    iterations           | 14        |
# |    time_elapsed         | 48        |
# |    total_timesteps      | 28672     |
# | train/                  |           |
# |    approx_kl            | 0.0188255 |
# |    clip_fraction        | 0.159     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.427    |
# |    explained_variance   | 0.157     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 3.62      |
# |    n_updates            | 130       |
# |    policy_gradient_loss | -0.0152   |
# |    value_loss           | 29.2      |
# ---------------------------------------
# Episode: 15,TP: 50.0, FP: 0.0, R: -76.07156694019
# TPR_h: 59.35, FPR_h: 32.19
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.99e+03   |
# |    ep_rew_mean          | 129        |
# | time/                   |            |
# |    fps                  | 597        |
# |    iterations           | 15         |
# |    time_elapsed         | 51         |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.01180917 |
# |    clip_fraction        | 0.119      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.42      |
# |    explained_variance   | 0.184      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.03       |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.0116    |
# |    value_loss           | 25.5       |
# ----------------------------------------
# Episode: 16,TP: 0.0, FP: 0.0, R: -51.73498785484001
# TPR_h: 75.4, FPR_h: 28.11
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 160         |
# | time/                   |             |
# |    fps                  | 598         |
# |    iterations           | 16          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.015849385 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.427      |
# |    explained_variance   | 0.0435      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.5        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0106     |
# |    value_loss           | 48.2        |
# -----------------------------------------
# Episode: 17,TP: 50.0, FP: 0.0, R: -54.49820911186
# TPR_h: 74.45, FPR_h: 30.2
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 182         |
# | time/                   |             |
# |    fps                  | 600         |
# |    iterations           | 17          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.011023076 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.417      |
# |    explained_variance   | 0.295       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.23        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0125     |
# |    value_loss           | 30.8        |
# -----------------------------------------
# Episode: 18,TP: 0.0, FP: 0.0, R: -82.60300480258998
# TPR_h: 50.81, FPR_h: 27.83
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.99e+03     |
# |    ep_rew_mean          | 175          |
# | time/                   |              |
# |    fps                  | 600          |
# |    iterations           | 18           |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0142604755 |
# |    clip_fraction        | 0.115        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.403       |
# |    explained_variance   | 0.402        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.48         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.0112      |
# |    value_loss           | 32.4         |
# ------------------------------------------
# Episode: 19,TP: 0.0, FP: 0.0, R: -78.62003123564001
# TPR_h: 53.75, FPR_h: 26.31
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 177         |
# | time/                   |             |
# |    fps                  | 600         |
# |    iterations           | 19          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.012916376 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.403      |
# |    explained_variance   | 0.15        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.05        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 47.6        |
# -----------------------------------------
# Episode: 20,TP: 50.0, FP: 0.0, R: -16.27955450689001
# TPR_h: 95.63, FPR_h: 26.69
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 216         |
# | time/                   |             |
# |    fps                  | 596         |
# |    iterations           | 20          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.014234944 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.326      |
# |    explained_variance   | 0.143       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.1        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00912    |
# |    value_loss           | 43          |
# -----------------------------------------
# Episode: 21,TP: 0.0, FP: 0.0, R: -87.00289021906
# TPR_h: 44.16, FPR_h: 24.5
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 207         |
# | time/                   |             |
# |    fps                  | 594         |
# |    iterations           | 21          |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.008426411 |
# |    clip_fraction        | 0.0737      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.323      |
# |    explained_variance   | 0.0208      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.6        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0102     |
# |    value_loss           | 15.2        |
# -----------------------------------------
# Episode: 22,TP: 0.0, FP: 0.0, R: -41.392873461239994
# TPR_h: 79.96, FPR_h: 22.22
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 229         |
# | time/                   |             |
# |    fps                  | 594         |
# |    iterations           | 22          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.014577689 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.364      |
# |    explained_variance   | 0.0229      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.14        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00772    |
# |    value_loss           | 50.5        |
# -----------------------------------------
# Episode: 23,TP: 0.0, FP: 0.0, R: -40.65515367660001
# TPR_h: 80.63, FPR_h: 22.89
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 255         |
# | time/                   |             |
# |    fps                  | 592         |
# |    iterations           | 23          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.009172341 |
# |    clip_fraction        | 0.0955      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.33       |
# |    explained_variance   | 0.404       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.5        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00713    |
# |    value_loss           | 21.1        |
# -----------------------------------------
# Episode: 24,TP: 0.0, FP: 0.0, R: -63.669130786100006
# TPR_h: 63.72, FPR_h: 19.94
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 268         |
# | time/                   |             |
# |    fps                  | 591         |
# |    iterations           | 24          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.015026744 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.341      |
# |    explained_variance   | 0.311       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.59        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00848    |
# |    value_loss           | 24.4        |
# -----------------------------------------
# Episode: 25,TP: 50.0, FP: 0.0, R: -92.0121349661
# TPR_h: 35.14, FPR_h: 20.13
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.99e+03   |
# |    ep_rew_mean          | 264        |
# | time/                   |            |
# |    fps                  | 591        |
# |    iterations           | 25         |
# |    time_elapsed         | 86         |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.02178444 |
# |    clip_fraction        | 0.145      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.345     |
# |    explained_variance   | 0.287      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 52.2       |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.00194   |
# |    value_loss           | 39.1       |
# ----------------------------------------
# Episode: 26,TP: 50.0, FP: 0.0, R: -43.06398902659001
# TPR_h: 78.82, FPR_h: 21.94
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 281         |
# | time/                   |             |
# |    fps                  | 591         |
# |    iterations           | 26          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.013189078 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.34       |
# |    explained_variance   | 0.194       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.04        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00802    |
# |    value_loss           | 61.6        |
# -----------------------------------------
# Episode: 27,TP: 50.0, FP: 0.0, R: -59.64565249235
# TPR_h: 66.38, FPR_h: 18.61
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 294         |
# | time/                   |             |
# |    fps                  | 591         |
# |    iterations           | 27          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.012292625 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.353      |
# |    explained_variance   | 0.315       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.55        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0052     |
# |    value_loss           | 28.5        |
# -----------------------------------------
# Episode: 28,TP: 0.0, FP: 0.0, R: -76.84204250081001
# TPR_h: 51.19, FPR_h: 16.9
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 296         |
# | time/                   |             |
# |    fps                  | 592         |
# |    iterations           | 28          |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.023006313 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.325      |
# |    explained_variance   | 0.379       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.34        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00582    |
# |    value_loss           | 35.1        |
# -----------------------------------------
# Episode: 29,TP: 50.0, FP: 0.0, R: -77.6338307815
# TPR_h: 52.9, FPR_h: 22.79
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 299         |
# | time/                   |             |
# |    fps                  | 593         |
# |    iterations           | 29          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.019288259 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.332      |
# |    explained_variance   | 0.218       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.23        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00818    |
# |    value_loss           | 49.6        |
# -----------------------------------------
# Episode: 30,TP: 50.0, FP: 0.0, R: -13.685817641940005
# TPR_h: 94.49, FPR_h: 16.71
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 326         |
# | time/                   |             |
# |    fps                  | 593         |
# |    iterations           | 30          |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.009548765 |
# |    clip_fraction        | 0.0743      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.213      |
# |    explained_variance   | 0.258       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 53.1        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00198    |
# |    value_loss           | 45.5        |
# -----------------------------------------
# Episode: 31,TP: 50.0, FP: 0.0, R: -37.05770489681001
# TPR_h: 81.39, FPR_h: 17.57
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 342         |
# | time/                   |             |
# |    fps                  | 592         |
# |    iterations           | 31          |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.008005882 |
# |    clip_fraction        | 0.0755      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.235      |
# |    explained_variance   | 0.512       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.4        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00657    |
# |    value_loss           | 16          |
# -----------------------------------------
# Episode: 32,TP: 50.0, FP: 0.0, R: -11.928017437040012
# TPR_h: 96.01, FPR_h: 19.56
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 367         |
# | time/                   |             |
# |    fps                  | 593         |
# |    iterations           | 32          |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.011766771 |
# |    clip_fraction        | 0.0776      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.18       |
# |    explained_variance   | 0.5         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.34        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00773    |
# |    value_loss           | 29.3        |
# -----------------------------------------
# Episode: 33,TP: 50.0, FP: 0.0, R: -37.249028412339996
# TPR_h: 81.29, FPR_h: 17.66
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 385         |
# | time/                   |             |
# |    fps                  | 593         |
# |    iterations           | 33          |
# |    time_elapsed         | 113         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.021316387 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.241      |
# |    explained_variance   | 0.514       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.29        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00563    |
# |    value_loss           | 17.4        |
# -----------------------------------------
# Episode: 34,TP: 50.0, FP: 0.0, R: -17.421436024040005
# TPR_h: 91.93, FPR_h: 13.58
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.99e+03     |
# |    ep_rew_mean          | 408          |
# | time/                   |              |
# |    fps                  | 593          |
# |    iterations           | 34           |
# |    time_elapsed         | 117          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0081720045 |
# |    clip_fraction        | 0.0566       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.182       |
# |    explained_variance   | 0.48         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.51         |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00581     |
# |    value_loss           | 28           |
# ------------------------------------------
# Episode: 35,TP: 50.0, FP: 0.0, R: -14.420385121959995
# TPR_h: 93.07, FPR_h: 10.16
# Episode: 36,TP: 50.0, FP: 0.0, R: -97.99200382946
# TPR_h: 17.57, FPR_h: 10.35
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 416         |
# | time/                   |             |
# |    fps                  | 592         |
# |    iterations           | 35          |
# |    time_elapsed         | 120         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.012790311 |
# |    clip_fraction        | 0.0541      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.144      |
# |    explained_variance   | 0.599       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.08        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00269    |
# |    value_loss           | 19.8        |
# -----------------------------------------
# Episode: 37,TP: 50.0, FP: 0.0, R: -76.40140664515002
# TPR_h: 50.33, FPR_h: 12.92
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.99e+03     |
# |    ep_rew_mean          | 415          |
# | time/                   |              |
# |    fps                  | 593          |
# |    iterations           | 36           |
# |    time_elapsed         | 124          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0073905364 |
# |    clip_fraction        | 0.0563       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.213       |
# |    explained_variance   | 0.233        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 28.2         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.0062      |
# |    value_loss           | 89.5         |
# ------------------------------------------
# Episode: 38,TP: 50.0, FP: 0.0, R: -82.07656029576
# TPR_h: 43.4, FPR_h: 9.59
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 418         |
# | time/                   |             |
# |    fps                  | 593         |
# |    iterations           | 37          |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.014077405 |
# |    clip_fraction        | 0.096       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.264      |
# |    explained_variance   | 0.391       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.8        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00673    |
# |    value_loss           | 49.7        |
# -----------------------------------------
# Episode: 39,TP: 0.0, FP: 0.0, R: -87.44704481131001
# TPR_h: 37.13, FPR_h: 11.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 413         |
# | time/                   |             |
# |    fps                  | 593         |
# |    iterations           | 38          |
# |    time_elapsed         | 131         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.009078107 |
# |    clip_fraction        | 0.0644      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.218      |
# |    explained_variance   | 0.218       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 114         |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00363    |
# |    value_loss           | 59.6        |
# -----------------------------------------
# Episode: 40,TP: 0.0, FP: 0.0, R: -87.85240707769002
# TPR_h: 35.61, FPR_h: 7.6
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 408         |
# | time/                   |             |
# |    fps                  | 592         |
# |    iterations           | 39          |
# |    time_elapsed         | 134         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.014776619 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.248      |
# |    explained_variance   | 0.274       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.84        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00349    |
# |    value_loss           | 57.6        |
# -----------------------------------------
# Episode: 41,TP: 50.0, FP: 0.0, R: -69.84285349814002
# TPR_h: 56.22, FPR_h: 11.87
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 414         |
# | time/                   |             |
# |    fps                  | 593         |
# |    iterations           | 40          |
# |    time_elapsed         | 138         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.020993311 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.229      |
# |    explained_variance   | 0.22        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35.2        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.000684   |
# |    value_loss           | 52.9        |
# -----------------------------------------
# Episode: 42,TP: 0.0, FP: 0.0, R: -17.389787185659998
# TPR_h: 92.97, FPR_h: 18.9
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 428         |
# | time/                   |             |
# |    fps                  | 593         |
# |    iterations           | 41          |
# |    time_elapsed         | 141         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.015771696 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.243      |
# |    explained_variance   | 0.23        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.72        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | 0.00042     |
# |    value_loss           | 42          |
# -----------------------------------------
# Episode: 43,TP: 0.0, FP: 0.0, R: -69.98513078534
# TPR_h: 55.84, FPR_h: 10.73
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 432         |
# | time/                   |             |
# |    fps                  | 593         |
# |    iterations           | 42          |
# |    time_elapsed         | 144         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.025304839 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.188      |
# |    explained_variance   | 0.322       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.78        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0088     |
# |    value_loss           | 18.9        |
# -----------------------------------------
# Episode: 44,TP: 50.0, FP: 0.0, R: -39.81870280054002
# TPR_h: 78.54, FPR_h: 12.06
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 445         |
# | time/                   |             |
# |    fps                  | 593         |
# |    iterations           | 43          |
# |    time_elapsed         | 148         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.017909717 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.22       |
# |    explained_variance   | 0.334       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.41        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0014     |
# |    value_loss           | 43.2        |
# -----------------------------------------
# Episode: 45,TP: 0.0, FP: 0.0, R: -65.61651370739
# TPR_h: 59.92, FPR_h: 12.16
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 452         |
# | time/                   |             |
# |    fps                  | 593         |
# |    iterations           | 44          |
# |    time_elapsed         | 151         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.014557741 |
# |    clip_fraction        | 0.0914      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.22       |
# |    explained_variance   | 0.593       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15          |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00874    |
# |    value_loss           | 26.1        |
# -----------------------------------------
# Episode: 46,TP: 50.0, FP: 0.0, R: -5.2899659933900125
# TPR_h: 98.29, FPR_h: 13.49
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.99e+03   |
# |    ep_rew_mean          | 469        |
# | time/                   |            |
# |    fps                  | 594        |
# |    iterations           | 45         |
# |    time_elapsed         | 155        |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.01224443 |
# |    clip_fraction        | 0.0855     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.197     |
# |    explained_variance   | 0.467      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.47       |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.00342   |
# |    value_loss           | 43.9       |
# ----------------------------------------
# Episode: 47,TP: 50.0, FP: 0.0, R: -9.966825789460003
# TPR_h: 95.73, FPR_h: 12.44
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 487         |
# | time/                   |             |
# |    fps                  | 594         |
# |    iterations           | 46          |
# |    time_elapsed         | 158         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.011911895 |
# |    clip_fraction        | 0.0544      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.125      |
# |    explained_variance   | 0.474       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.88        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00377    |
# |    value_loss           | 14.5        |
# -----------------------------------------
# Episode: 48,TP: 50.0, FP: 0.0, R: -63.65294259404
# TPR_h: 62.2, FPR_h: 14.91
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 490         |
# | time/                   |             |
# |    fps                  | 594         |
# |    iterations           | 47          |
# |    time_elapsed         | 161         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.026652234 |
# |    clip_fraction        | 0.0741      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.171      |
# |    explained_variance   | 0.604       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.75        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.01       |
# |    value_loss           | 16.2        |
# -----------------------------------------
# Episode: 49,TP: 50.0, FP: 0.0, R: -44.042400514160015
# TPR_h: 75.97, FPR_h: 13.01
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 497         |
# | time/                   |             |
# |    fps                  | 594         |
# |    iterations           | 48          |
# |    time_elapsed         | 165         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.022828117 |
# |    clip_fraction        | 0.0788      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.222      |
# |    explained_variance   | 0.324       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22          |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00556    |
# |    value_loss           | 47.8        |
# -----------------------------------------
# Episode: 50,TP: 0.0, FP: 0.0, R: -94.07679786184
# TPR_h: 33.62, FPR_h: 22.32
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 486         |
# | time/                   |             |
# |    fps                  | 594         |
# |    iterations           | 49          |
# |    time_elapsed         | 168         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.012617496 |
# |    clip_fraction        | 0.0847      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.23       |
# |    explained_variance   | 0.388       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.71        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00484    |
# |    value_loss           | 35.6        |
# -----------------------------------------
# Episode: 51,TP: 50.0, FP: 0.0, R: -30.971030179390013
# TPR_h: 84.52, FPR_h: 15.1
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 495         |
# | time/                   |             |
# |    fps                  | 595         |
# |    iterations           | 50          |
# |    time_elapsed         | 172         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.013802858 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.271      |
# |    explained_variance   | 0.302       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 89.3        |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00169    |
# |    value_loss           | 62.9        |
# -----------------------------------------
# Episode: 52,TP: 0.0, FP: 0.0, R: -57.74161835339001
# TPR_h: 66.86, FPR_h: 15.19
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 496         |
# | time/                   |             |
# |    fps                  | 595         |
# |    iterations           | 51          |
# ...
# Episode: 953,TP: 50.0, FP: 0.0, R: -10.536240288160002
# TPR_h: 95.92, FPR_h: 15.48
# Episode: 954,TP: 50.0, FP: 0.0, R: -5.504631115899984
# TPR_h: 97.34, FPR_h: 5.7
# Episode: 955,TP: 50.0, FP: 0.0, R: -19.565456418740013
# TPR_h: 90.03, FPR_h: 8.07
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 1.19e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 625      |
# |    time_elapsed     | 1400     |
# |    total_timesteps  | 875600   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.284    |
# |    n_updates        | 218874   |
# ----------------------------------
# Episode: 956,TP: 0.0, FP: 0.0, R: -47.28383189764
# TPR_h: 73.03, FPR_h: 8.07
# Episode: 957,TP: 50.0, FP: 0.0, R: -21.652085259539987
# TPR_h: 88.98, FPR_h: 9.21
# Episode: 958,TP: 50.0, FP: 0.0, R: -12.515063481789994
# TPR_h: 93.73, FPR_h: 6.55
# Episode: 959,TP: 50.0, FP: 0.0, R: -12.515063481789994
# TPR_h: 93.73, FPR_h: 6.55
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 1.19e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 625      |
# |    time_elapsed     | 1412     |
# |    total_timesteps  | 883560   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.173    |
# |    n_updates        | 220864   |
# ----------------------------------
# Episode: 960,TP: 50.0, FP: 0.0, R: -24.177582344809988
# TPR_h: 87.08, FPR_h: 3.23
# Episode: 961,TP: 50.0, FP: 0.0, R: -12.88449217529002
# TPR_h: 93.54, FPR_h: 6.65
# Episode: 962,TP: 50.0, FP: 0.0, R: -38.20862290376
# TPR_h: 78.92, FPR_h: 7.31
# Episode: 963,TP: 50.0, FP: 0.0, R: -20.202246196559997
# TPR_h: 89.84, FPR_h: 9.59
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 1.19e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 625      |
# |    time_elapsed     | 1425     |
# |    total_timesteps  | 891520   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.345    |
# |    n_updates        | 222854   |
# ----------------------------------
# Episode: 964,TP: 50.0, FP: 0.0, R: -9.13132806211
# TPR_h: 95.44, FPR_h: 5.41
# Episode: 965,TP: 50.0, FP: 0.0, R: -18.912752566909987
# TPR_h: 90.22, FPR_h: 6.08
# Episode: 966,TP: 50.0, FP: 0.0, R: -6.216824908240015
# TPR_h: 97.15, FPR_h: 7.98
# Episode: 967,TP: 50.0, FP: 0.0, R: -6.558647646440009
# TPR_h: 96.68, FPR_h: 3.32
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 1.19e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 625      |
# |    time_elapsed     | 1438     |
# |    total_timesteps  | 899480   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.176    |
# |    n_updates        | 224844   |
# ----------------------------------
# Episode: 968,TP: 50.0, FP: 0.0, R: -10.068413877160026
# TPR_h: 94.87, FPR_h: 3.99
# Episode: 969,TP: 50.0, FP: 0.0, R: -7.1708402821100075
# TPR_h: 96.68, FPR_h: 8.17
# Episode: 970,TP: 50.0, FP: 0.0, R: -5.298383202489987
# TPR_h: 97.34, FPR_h: 3.7
# Episode: 971,TP: 50.0, FP: 0.0, R: -11.229361063789979
# TPR_h: 94.3, FPR_h: 4.84
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 1.2e+03  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 625      |
# |    time_elapsed     | 1451     |
# |    total_timesteps  | 907440   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.291    |
# |    n_updates        | 226834   |
# ----------------------------------
# Episode: 972,TP: 0.0, FP: 0.0, R: -44.86785840665
# TPR_h: 74.55, FPR_h: 7.03
# Episode: 973,TP: 50.0, FP: 0.0, R: -12.468130723960003
# TPR_h: 93.83, FPR_h: 7.41
# Episode: 974,TP: 50.0, FP: 0.0, R: -46.43131650131
# TPR_h: 73.69, FPR_h: 8.74
# Episode: 975,TP: 50.0, FP: 0.0, R: -5.8812086184099845
# TPR_h: 97.34, FPR_h: 8.17
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 1.2e+03  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 624      |
# |    time_elapsed     | 1466     |
# |    total_timesteps  | 915400   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.364    |
# |    n_updates        | 228824   |
# ----------------------------------
# Episode: 976,TP: 50.0, FP: 0.0, R: -5.26255391254
# TPR_h: 97.44, FPR_h: 5.22
# Episode: 977,TP: 50.0, FP: 0.0, R: -6.320395289000019
# TPR_h: 97.15, FPR_h: 8.55
# Episode: 978,TP: 50.0, FP: 0.0, R: -29.041699661690004
# TPR_h: 84.9, FPR_h: 10.54
# Episode: 979,TP: 50.0, FP: 0.0, R: -14.876318885660012
# TPR_h: 92.31, FPR_h: 4.08
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 1.2e+03  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 624      |
# |    time_elapsed     | 1478     |
# |    total_timesteps  | 923360   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.303    |
# |    n_updates        | 230814   |
# ----------------------------------
# Episode: 980,TP: 50.0, FP: 0.0, R: -11.63652257819001
# TPR_h: 94.21, FPR_h: 6.65
# Episode: 981,TP: 50.0, FP: 0.0, R: -8.867937299860003
# TPR_h: 95.73, FPR_h: 7.41
# Episode: 982,TP: 50.0, FP: 0.0, R: -45.29853196769002
# TPR_h: 74.07, FPR_h: 4.94
# Episode: 983,TP: 50.0, FP: 0.0, R: -29.45808590886
# TPR_h: 84.24, FPR_h: 6.84
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 1.21e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 624      |
# |    time_elapsed     | 1491     |
# |    total_timesteps  | 931320   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.422    |
# |    n_updates        | 232804   |
# ----------------------------------
# Episode: 984,TP: 50.0, FP: 0.0, R: -21.435419949139984
# TPR_h: 88.98, FPR_h: 8.07
# Episode: 985,TP: 50.0, FP: 0.0, R: -12.454643640410014
# TPR_h: 93.92, FPR_h: 8.36
# Episode: 986,TP: 50.0, FP: 0.0, R: -17.185473680060014
# TPR_h: 91.07, FPR_h: 4.56
# Episode: 987,TP: 50.0, FP: 0.0, R: -23.35503882724001
# TPR_h: 87.56, FPR_h: 3.32
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 1.21e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 624      |
# |    time_elapsed     | 1504     |
# |    total_timesteps  | 939280   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.33     |
# |    n_updates        | 234794   |
# ----------------------------------
# Episode: 988,TP: 50.0, FP: 0.0, R: -34.751624214589995
# TPR_h: 81.01, FPR_h: 6.55
# Episode: 989,TP: 50.0, FP: 0.0, R: -15.438583793389993
# TPR_h: 93.26, FPR_h: 15.1
# Episode: 990,TP: 50.0, FP: 0.0, R: -11.27987079809
# TPR_h: 94.49, FPR_h: 7.79
# Episode: 991,TP: 0.0, FP: 0.0, R: -52.28481065734001
# TPR_h: 69.33, FPR_h: 6.36
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 1.21e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 624      |
# |    time_elapsed     | 1517     |
# |    total_timesteps  | 947240   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.14     |
# |    n_updates        | 236784   |
# ----------------------------------
# Episode: 992,TP: 50.0, FP: 0.0, R: -9.258513560190025
# TPR_h: 95.35, FPR_h: 4.94
# Episode: 993,TP: 50.0, FP: 0.0, R: -11.352668990509983
# TPR_h: 94.3, FPR_h: 5.89
# Episode: 994,TP: 50.0, FP: 0.0, R: -6.682723147640019
# TPR_h: 96.58, FPR_h: 2.37
# Episode: 995,TP: 50.0, FP: 0.0, R: -13.770241090109991
# TPR_h: 93.26, FPR_h: 8.74
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 1.22e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 623      |
# |    time_elapsed     | 1530     |
# |    total_timesteps  | 955200   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.133    |
# |    n_updates        | 238774   |
# ----------------------------------
# Episode: 996,TP: 50.0, FP: 0.0, R: -7.821095086190013
# TPR_h: 96.58, FPR_h: 10.45
# Episode: 997,TP: 50.0, FP: 0.0, R: -29.35160419818999
# TPR_h: 84.14, FPR_h: 4.75
# Episode: 998,TP: 50.0, FP: 0.0, R: -9.607791406409987
# TPR_h: 95.82, FPR_h: 11.78
# Episode: 999,TP: 50.0, FP: 0.0, R: -6.780772495540007
# TPR_h: 96.96, FPR_h: 9.02
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 1.21e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 623      |
# |    time_elapsed     | 1543     |
# |    total_timesteps  | 963160   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.194    |
# |    n_updates        | 240764   |
# ----------------------------------
# Episode: 1000,TP: 50.0, FP: 0.0, R: -25.610771082560003
# TPR_h: 86.8, FPR_h: 9.78
# Episode: 1001,TP: 50.0, FP: 0.0, R: -6.509444232510007
# TPR_h: 96.68, FPR_h: 2.56
# Episode: 1002,TP: 50.0, FP: 0.0, R: -21.980707248239995
# TPR_h: 88.51, FPR_h: 6.17
# Episode: 1003,TP: 50.0, FP: 0.0, R: -6.1649252038999975
# TPR_h: 96.87, FPR_h: 2.94
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 1.22e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 623      |
# |    time_elapsed     | 1556     |
# |    total_timesteps  | 971120   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.181    |
# |    n_updates        | 242754   |
# ----------------------------------
# Episode: 1004,TP: 50.0, FP: 0.0, R: -18.502816598189995
# TPR_h: 90.88, FPR_h: 10.45
# Episode: 1005,TP: 50.0, FP: 0.0, R: -13.933459087689997
# TPR_h: 92.97, FPR_h: 6.55
# Episode: 1006,TP: 50.0, FP: 0.0, R: -17.69416874276
# TPR_h: 90.79, FPR_h: 4.46
# Episode: 1007,TP: 50.0, FP: 0.0, R: -27.037924511360004
# TPR_h: 85.66, FPR_h: 6.84
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 1.22e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 623      |
# |    time_elapsed     | 1569     |
# |    total_timesteps  | 979080   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.206    |
# |    n_updates        | 244744   |
# ----------------------------------
# Episode: 1008,TP: 50.0, FP: 0.0, R: -50.597431882460015
# TPR_h: 70.66, FPR_h: 7.5
# Episode: 1009,TP: 50.0, FP: 0.0, R: -16.415877998260015
# TPR_h: 91.64, FPR_h: 6.74
# Episode: 1010,TP: 0.0, FP: 0.0, R: -44.49046605211001
# TPR_h: 74.93, FPR_h: 8.17
# Episode: 1011,TP: 50.0, FP: 0.0, R: -10.213158179960004
# TPR_h: 94.97, FPR_h: 6.74
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 1.21e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 623      |
# |    time_elapsed     | 1582     |
# |    total_timesteps  | 987040   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.371    |
# |    n_updates        | 246734   |
# ----------------------------------
# Episode: 1012,TP: 50.0, FP: 0.0, R: -6.61560510464001
# TPR_h: 97.06, FPR_h: 9.12
# Episode: 1013,TP: 0.0, FP: 0.0, R: -53.27714842409002
# TPR_h: 68.76, FPR_h: 7.69
# Episode: 1014,TP: 0.0, FP: 0.0, R: -32.95079023826001
# TPR_h: 81.96, FPR_h: 4.46
# Episode: 1015,TP: 50.0, FP: 0.0, R: -30.83214825735999
# TPR_h: 84.14, FPR_h: 12.54
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 1.2e+03  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 623      |
# |    time_elapsed     | 1595     |
# |    total_timesteps  | 995000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.221    |
# |    n_updates        | 248724   |
# ----------------------------------
# Episode: 1016,TP: 50.0, FP: 0.0, R: -6.964908335540002
# TPR_h: 96.87, FPR_h: 9.02
# Episode: 1017,TP: 50.0, FP: 0.0, R: -29.55153772424002
# TPR_h: 83.95, FPR_h: 3.42
# Episode: 1018,TP: 50.0, FP: 0.0, R: -10.325554132840026
# TPR_h: 94.87, FPR_h: 6.27
# Episode: 1019,TP: 50.0, FP: 0.0, R: -41.780843548060005
# TPR_h: 76.92, FPR_h: 9.78
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 1.2e+03  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 504      |
# |    fps              | 623      |
# |    time_elapsed     | 1608     |
# |    total_timesteps  | 1002960  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.442    |
# |    n_updates        | 250714   |
# ----------------------------------
# Episode: 1020,TP: 50.0, FP: 0.0, R: -8.24322383785001
# TPR_h: 96.3, FPR_h: 9.88
# Episode: 1021,TP: 50.0, FP: 0.0, R: -8.222760278110002
# TPR_h: 95.92, FPR_h: 5.41
# Episode: 1022,TP: 50.0, FP: 0.0, R: -11.901595092409991
# TPR_h: 94.02, FPR_h: 5.98
# Episode: 1023,TP: 50.0, FP: 0.0, R: -46.3798940741
# TPR_h: 73.41, FPR_h: 5.79
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 1.2e+03  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 508      |
# |    fps              | 623      |
# |    time_elapsed     | 1621     |
# |    total_timesteps  | 1010920  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.231    |
# |    n_updates        | 252704   |
# ----------------------------------
# Episode: 1024,TP: 50.0, FP: 0.0, R: -39.695865433609995
# TPR_h: 78.06, FPR_h: 8.17
# Episode: 1025,TP: 50.0, FP: 0.0, R: -16.483382976509986
# TPR_h: 91.55, FPR_h: 5.98
# Episode: 1026,TP: 50.0, FP: 0.0, R: -5.52812071241
# TPR_h: 97.53, FPR_h: 8.26
# Episode: 1027,TP: 50.0, FP: 0.0, R: -22.47143134440998
# TPR_h: 88.22, FPR_h: 6.08
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 1.2e+03  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 512      |
# |    fps              | 623      |
# |    time_elapsed     | 1634     |
# |    total_timesteps  | 1018880  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.386    |
# |    n_updates        | 254694   |
# ----------------------------------

# %%
# Assuming the data variable is already defined and loaded with the appropriate shape
# data = np.load('your_data.npy')  # Load your data here
snr = 0
data = c_states[snr]
# env = DummyVecEnv([lambda: FrequencyDetectionEnv(data)])
env = FrequencyDetectionEnv(data)
# Train PPO model
# model_ppo = PPO('MlpPolicy', env, verbose=1)
model_ppo.learn(total_timesteps=120*17*500)

env.reset()

# Train DQN model
# model_dqn = DQN('MlpPolicy', env, verbose=1)
model_dqn.learn(total_timesteps=120*17*500)
# Out:
# Episode: 1029,TP: 50.0, FP: 0.0, R: -4.712002171150019
# TPR_h: 98.96, FPR_h: 15.76
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.99e+03 |
# |    ep_rew_mean     | 1.21e+03 |
# | time/              |          |
# |    fps             | 1048     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode: 1030,TP: 50.0, FP: 0.0, R: -50.87784997811001
# TPR_h: 71.51, FPR_h: 13.87
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 943         |
# | time/                   |             |
# |    fps                  | 704         |
# |    iterations           | 2           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.022420019 |
# |    clip_fraction        | 0.055       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0742     |
# |    explained_variance   | 0.973       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.87        |
# |    n_updates            | 5000        |
# |    policy_gradient_loss | 0.00693     |
# |    value_loss           | 5.85        |
# -----------------------------------------
# Episode: 1031,TP: 50.0, FP: 0.0, R: -22.364198434809992
# TPR_h: 88.89, FPR_h: 11.59
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 984         |
# | time/                   |             |
# |    fps                  | 639         |
# |    iterations           | 3           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.029237635 |
# |    clip_fraction        | 0.0986      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.145      |
# |    explained_variance   | 0.913       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.5         |
# |    n_updates            | 5010        |
# |    policy_gradient_loss | 0.00239     |
# |    value_loss           | 17.6        |
# -----------------------------------------
# Episode: 1032,TP: 50.0, FP: 0.0, R: -2.4256152552599985
# TPR_h: 99.24, FPR_h: 9.59
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 1.07e+03    |
# | time/                   |             |
# |    fps                  | 613         |
# |    iterations           | 4           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.025848199 |
# |    clip_fraction        | 0.0499      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.1        |
# |    explained_variance   | 0.956       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.88        |
# |    n_updates            | 5020        |
# |    policy_gradient_loss | -0.00089    |
# |    value_loss           | 7.08        |
# -----------------------------------------
# Episode: 1033,TP: 50.0, FP: 0.0, R: -6.980366854350009
# TPR_h: 96.68, FPR_h: 7.03
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.99e+03   |
# |    ep_rew_mean          | 1.12e+03   |
# | time/                   |            |
# |    fps                  | 599        |
# |    iterations           | 5          |
# |    time_elapsed         | 17         |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.01043232 |
# |    clip_fraction        | 0.0439     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0587    |
# |    explained_variance   | 0.975      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.58       |
# |    n_updates            | 5030       |
# |    policy_gradient_loss | -0.00414   |
# |    value_loss           | 3.87       |
# ----------------------------------------
# Episode: 1034,TP: 50.0, FP: 0.0, R: -42.097414067239995
# TPR_h: 78.25, FPR_h: 17.66
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.99e+03   |
# |    ep_rew_mean          | 1.04e+03   |
# | time/                   |            |
# |    fps                  | 593        |
# |    iterations           | 6          |
# |    time_elapsed         | 20         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.02937651 |
# |    clip_fraction        | 0.055      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0575    |
# |    explained_variance   | 0.976      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.75       |
# |    n_updates            | 5040       |
# |    policy_gradient_loss | -0.00239   |
# |    value_loss           | 3.93       |
# ----------------------------------------
# Episode: 1035,TP: 50.0, FP: 0.0, R: -56.57256719579
# TPR_h: 66.19, FPR_h: 6.65
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 1.02e+03    |
# | time/                   |             |
# |    fps                  | 584         |
# |    iterations           | 7           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.057908192 |
# |    clip_fraction        | 0.0953      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0754     |
# |    explained_variance   | 0.91        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.8        |
# |    n_updates            | 5050        |
# |    policy_gradient_loss | 0.00626     |
# |    value_loss           | 12.3        |
# -----------------------------------------
# Episode: 1036,TP: 0.0, FP: 0.0, R: -74.13894735019001
# TPR_h: 51.38, FPR_h: 7.6
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 969         |
# | time/                   |             |
# |    fps                  | 581         |
# |    iterations           | 8           |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.017472267 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.206      |
# |    explained_variance   | 0.933       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.3        |
# |    n_updates            | 5060        |
# |    policy_gradient_loss | -0.00437    |
# |    value_loss           | 18.4        |
# -----------------------------------------
# Episode: 1037,TP: 0.0, FP: 0.0, R: -40.59938975641
# TPR_h: 77.49, FPR_h: 8.26
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.99e+03     |
# |    ep_rew_mean          | 965          |
# | time/                   |              |
# |    fps                  | 578          |
# |    iterations           | 9            |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0076914877 |
# |    clip_fraction        | 0.109        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.194       |
# |    explained_variance   | 0.902        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.7          |
# |    n_updates            | 5070         |
# |    policy_gradient_loss | 0.00063      |
# |    value_loss           | 22.1         |
# ------------------------------------------
# Episode: 1038,TP: 50.0, FP: 0.0, R: -47.30915241986
# TPR_h: 72.93, FPR_h: 7.41
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 973         |
# | time/                   |             |
# |    fps                  | 575         |
# |    iterations           | 10          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.032471392 |
# |    clip_fraction        | 0.0929      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.134      |
# |    explained_variance   | 0.964       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3           |
# |    n_updates            | 5080        |
# |    policy_gradient_loss | 0.000626    |
# |    value_loss           | 8.64        |
# -----------------------------------------
# Episode: 1039,TP: 50.0, FP: 0.0, R: -63.85671461561
# TPR_h: 60.3, FPR_h: 5.41
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 953         |
# | time/                   |             |
# |    fps                  | 573         |
# |    iterations           | 11          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.043272845 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.149      |
# |    explained_variance   | 0.948       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.33        |
# |    n_updates            | 5090        |
# |    policy_gradient_loss | 0.0194      |
# |    value_loss           | 12.2        |
# -----------------------------------------
# Episode: 1040,TP: 0.0, FP: 0.0, R: -68.95412218361001
# TPR_h: 56.32, FPR_h: 8.36
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 929         |
# | time/                   |             |
# |    fps                  | 571         |
# |    iterations           | 12          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.010052269 |
# |    clip_fraction        | 0.0552      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.142      |
# |    explained_variance   | 0.912       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.13        |
# |    n_updates            | 5100        |
# |    policy_gradient_loss | 0.000789    |
# |    value_loss           | 20.1        |
# -----------------------------------------
# Episode: 1041,TP: 50.0, FP: 0.0, R: -2.9119876971500105
# TPR_h: 98.77, FPR_h: 7.12
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 965         |
# | time/                   |             |
# |    fps                  | 570         |
# |    iterations           | 13          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.025626715 |
# |    clip_fraction        | 0.088       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.122      |
# |    explained_variance   | 0.838       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.92        |
# |    n_updates            | 5110        |
# |    policy_gradient_loss | 0.00559     |
# |    value_loss           | 24.8        |
# -----------------------------------------
# Episode: 1042,TP: 50.0, FP: 0.0, R: -0.9920875816100221
# TPR_h: 99.62, FPR_h: 5.51
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 999         |
# | time/                   |             |
# |    fps                  | 570         |
# |    iterations           | 14          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.023986371 |
# |    clip_fraction        | 0.0621      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0767     |
# |    explained_variance   | 0.968       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.27        |
# |    n_updates            | 5120        |
# |    policy_gradient_loss | 0.0181      |
# |    value_loss           | 5.35        |
# -----------------------------------------
# Episode: 1043,TP: 50.0, FP: 0.0, R: -30.186788817340002
# TPR_h: 83.76, FPR_h: 6.36
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 1e+03       |
# | time/                   |             |
# |    fps                  | 568         |
# |    iterations           | 15          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.010995282 |
# |    clip_fraction        | 0.0349      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0603     |
# |    explained_variance   | 0.887       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.45        |
# |    n_updates            | 5130        |
# |    policy_gradient_loss | 2.31e-05    |
# |    value_loss           | 4.16        |
# -----------------------------------------
# Episode: 1044,TP: 50.0, FP: 0.0, R: -47.94956874374001
# TPR_h: 72.27, FPR_h: 5.03
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 997         |
# | time/                   |             |
# |    fps                  | 567         |
# |    iterations           | 16          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.016892139 |
# |    clip_fraction        | 0.0659      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0947     |
# |    explained_variance   | 0.938       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.97        |
# |    n_updates            | 5140        |
# |    policy_gradient_loss | -0.00321    |
# |    value_loss           | 10.4        |
# -----------------------------------------
# Episode: 1045,TP: 50.0, FP: 0.0, R: -42.76340100809001
# TPR_h: 75.69, FPR_h: 3.7
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 994         |
# | time/                   |             |
# |    fps                  | 566         |
# |    iterations           | 17          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.016855154 |
# |    clip_fraction        | 0.0763      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.112      |
# |    explained_variance   | 0.96        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.64        |
# |    n_updates            | 5150        |
# |    policy_gradient_loss | 0.00174     |
# |    value_loss           | 9.65        |
# -----------------------------------------
# Episode: 1046,TP: 50.0, FP: 0.0, R: -19.19402157650002
# TPR_h: 90.03, FPR_h: 5.6
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 1.01e+03    |
# | time/                   |             |
# |    fps                  | 566         |
# |    iterations           | 18          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.004648994 |
# |    clip_fraction        | 0.0396      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.104      |
# |    explained_variance   | 0.928       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.01        |
# |    n_updates            | 5160        |
# |    policy_gradient_loss | -0.000808   |
# |    value_loss           | 12.2        |
# -----------------------------------------
# Episode: 1047,TP: 50.0, FP: 0.0, R: -13.71002063441
# TPR_h: 92.88, FPR_h: 2.56
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.99e+03   |
# |    ep_rew_mean          | 1.03e+03   |
# | time/                   |            |
# |    fps                  | 565        |
# |    iterations           | 19         |
# |    time_elapsed         | 68         |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.04523413 |
# |    clip_fraction        | 0.0668     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0615    |
# |    explained_variance   | 0.979      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.46       |
# |    n_updates            | 5170       |
# |    policy_gradient_loss | 0.015      |
# |    value_loss           | 4.73       |
# ----------------------------------------
# Episode: 1048,TP: 50.0, FP: 0.0, R: -45.89657649785001
# TPR_h: 73.5, FPR_h: 1.52
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 1.02e+03    |
# | time/                   |             |
# |    fps                  | 565         |
# |    iterations           | 20          |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.018494692 |
# |    clip_fraction        | 0.0314      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0668     |
# |    explained_variance   | 0.944       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.27        |
# |    n_updates            | 5180        |
# |    policy_gradient_loss | -0.0012     |
# |    value_loss           | 5.94        |
# -----------------------------------------
# Episode: 1049,TP: 50.0, FP: 0.0, R: -17.958357414810024
# TPR_h: 90.69, FPR_h: 5.32
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.99e+03   |
# |    ep_rew_mean          | 1.03e+03   |
# | time/                   |            |
# |    fps                  | 564        |
# |    iterations           | 21         |
# |    time_elapsed         | 76         |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.06346443 |
# |    clip_fraction        | 0.0419     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0547    |
# |    explained_variance   | 0.907      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 20.4       |
# |    n_updates            | 5190       |
# |    policy_gradient_loss | 0.00452    |
# |    value_loss           | 14.4       |
# ----------------------------------------
# Episode: 1050,TP: 50.0, FP: 0.0, R: -5.948970475240016
# TPR_h: 97.15, FPR_h: 6.27
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 1.04e+03    |
# | time/                   |             |
# |    fps                  | 565         |
# |    iterations           | 22          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.015325573 |
# |    clip_fraction        | 0.0571      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0857     |
# |    explained_variance   | 0.962       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.85        |
# |    n_updates            | 5200        |
# |    policy_gradient_loss | -0.00193    |
# |    value_loss           | 5.6         |
# -----------------------------------------
# Episode: 1051,TP: 50.0, FP: 0.0, R: -18.906116593659988
# TPR_h: 90.12, FPR_h: 4.56
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.99e+03   |
# |    ep_rew_mean          | 1.06e+03   |
# | time/                   |            |
# |    fps                  | 564        |
# |    iterations           | 23         |
# |    time_elapsed         | 83         |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.01036125 |
# |    clip_fraction        | 0.0426     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.068     |
# |    explained_variance   | 0.966      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.34       |
# |    n_updates            | 5210       |
# |    policy_gradient_loss | 0.00118    |
# |    value_loss           | 3.54       |
# ----------------------------------------
# Episode: 1052,TP: 50.0, FP: 0.0, R: -45.46241557714001
# TPR_h: 74.07, FPR_h: 6.27
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.99e+03     |
# |    ep_rew_mean          | 1.05e+03     |
# | time/                   |              |
# |    fps                  | 564          |
# |    iterations           | 24           |
# |    time_elapsed         | 87           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0061512133 |
# |    clip_fraction        | 0.0399       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0788      |
# |    explained_variance   | 0.926        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.98         |
# |    n_updates            | 5220         |
# |    policy_gradient_loss | -0.000475    |
# |    value_loss           | 7.53         |
# ------------------------------------------
# Episode: 1053,TP: 50.0, FP: 0.0, R: -15.97014615206001
# TPR_h: 91.74, FPR_h: 4.56
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 1.06e+03    |
# | time/                   |             |
# |    fps                  | 563         |
# |    iterations           | 25          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.060902193 |
# |    clip_fraction        | 0.0896      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0818     |
# |    explained_variance   | 0.908       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.61        |
# |    n_updates            | 5230        |
# |    policy_gradient_loss | 0.0158      |
# |    value_loss           | 12.4        |
# -----------------------------------------
# Episode: 1054,TP: 50.0, FP: 0.0, R: -2.2808968657100053
# TPR_h: 98.86, FPR_h: 3.23
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 1.07e+03    |
# | time/                   |             |
# |    fps                  | 563         |
# |    iterations           | 26          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.013293175 |
# |    clip_fraction        | 0.0527      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0624     |
# |    explained_variance   | 0.931       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.21        |
# |    n_updates            | 5240        |
# |    policy_gradient_loss | 0.00676     |
# |    value_loss           | 7.31        |
# -----------------------------------------
# Episode: 1055,TP: 50.0, FP: 0.0, R: -0.1892827876400105
# TPR_h: 100.0, FPR_h: 5.13
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.99e+03     |
# |    ep_rew_mean          | 1.09e+03     |
# | time/                   |              |
# |    fps                  | 562          |
# |    iterations           | 27           |
# |    time_elapsed         | 98           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0027568021 |
# |    clip_fraction        | 0.0202       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0298      |
# |    explained_variance   | 0.937        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.23         |
# |    n_updates            | 5250         |
# |    policy_gradient_loss | -0.0018      |
# |    value_loss           | 5.51         |
# ------------------------------------------
# Episode: 1056,TP: 50.0, FP: 0.0, R: -58.822624632339995
# TPR_h: 64.2, FPR_h: 3.51
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.99e+03     |
# |    ep_rew_mean          | 1.08e+03     |
# | time/                   |              |
# |    fps                  | 562          |
# |    iterations           | 28           |
# |    time_elapsed         | 102          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0054576686 |
# |    clip_fraction        | 0.0426       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0853      |
# |    explained_variance   | 0.827        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.46         |
# |    n_updates            | 5260         |
# |    policy_gradient_loss | -0.00289     |
# |    value_loss           | 8.97         |
# ------------------------------------------
# Episode: 1057,TP: 50.0, FP: 0.0, R: -84.40958727265003
# TPR_h: 39.6, FPR_h: 4.18
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 1.05e+03    |
# | time/                   |             |
# |    fps                  | 561         |
# |    iterations           | 29          |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.029830137 |
# |    clip_fraction        | 0.089       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.116      |
# |    explained_variance   | 0.732       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.2        |
# |    n_updates            | 5270        |
# |    policy_gradient_loss | 0.0158      |
# |    value_loss           | 27.2        |
# -----------------------------------------
# Episode: 1058,TP: 50.0, FP: 0.0, R: -11.070728034639998
# TPR_h: 94.4, FPR_h: 5.03
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 1.06e+03    |
# | time/                   |             |
# |    fps                  | 561         |
# |    iterations           | 30          |
# |    time_elapsed         | 109         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.053582907 |
# |    clip_fraction        | 0.0449      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0666     |
# |    explained_variance   | 0.808       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.28        |
# |    n_updates            | 5280        |
# |    policy_gradient_loss | 0.0166      |
# |    value_loss           | 31.1        |
# -----------------------------------------
# Episode: 1059,TP: 50.0, FP: 0.0, R: -1.0819701697900115
# TPR_h: 99.91, FPR_h: 9.5
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 1.07e+03    |
# | time/                   |             |
# |    fps                  | 561         |
# |    iterations           | 31          |
# |    time_elapsed         | 113         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.019059531 |
# |    clip_fraction        | 0.0362      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0448     |
# |    explained_variance   | 0.963       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.52        |
# |    n_updates            | 5290        |
# |    policy_gradient_loss | 0.00173     |
# |    value_loss           | 4.03        |
# -----------------------------------------
# Episode: 1060,TP: 50.0, FP: 0.0, R: -10.024173041310007
# TPR_h: 94.97, FPR_h: 5.32
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 1.08e+03    |
# | time/                   |             |
# |    fps                  | 560         |
# |    iterations           | 32          |
# |    time_elapsed         | 116         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.008809572 |
# |    clip_fraction        | 0.0398      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0615     |
# |    explained_variance   | 0.961       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.576       |
# |    n_updates            | 5300        |
# |    policy_gradient_loss | 0.00621     |
# |    value_loss           | 4.28        |
# -----------------------------------------
# Episode: 1061,TP: 50.0, FP: 0.0, R: -2.947849332659999
# TPR_h: 98.58, FPR_h: 4.46
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 1.09e+03    |
# | time/                   |             |
# |    fps                  | 560         |
# |    iterations           | 33          |
# |    time_elapsed         | 120         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.002323124 |
# |    clip_fraction        | 0.0213      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0407     |
# |    explained_variance   | 0.967       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.86        |
# |    n_updates            | 5310        |
# |    policy_gradient_loss | -0.00235    |
# |    value_loss           | 7.51        |
# -----------------------------------------
# Episode: 1062,TP: 50.0, FP: 0.0, R: -44.057755114190016
# TPR_h: 74.83, FPR_h: 3.8
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.99e+03   |
# |    ep_rew_mean          | 1.09e+03   |
# | time/                   |            |
# |    fps                  | 559        |
# |    iterations           | 34         |
# |    time_elapsed         | 124        |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.01843749 |
# |    clip_fraction        | 0.0484     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0742    |
# |    explained_variance   | 0.933      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.25       |
# |    n_updates            | 5320       |
# |    policy_gradient_loss | -0.00292   |
# |    value_loss           | 8.89       |
# ----------------------------------------
# Episode: 1063,TP: 50.0, FP: 0.0, R: -8.78239429573999
# TPR_h: 95.82, FPR_h: 7.98
# Episode: 1064,TP: 50.0, FP: 0.0, R: -13.487492949439982
# TPR_h: 93.64, FPR_h: 10.73
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 1.1e+03     |
# | time/                   |             |
# |    fps                  | 559         |
# |    iterations           | 35          |
# |    time_elapsed         | 128         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.019888606 |
# |    clip_fraction        | 0.0528      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.07       |
# |    explained_variance   | 0.918       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.89        |
# |    n_updates            | 5330        |
# |    policy_gradient_loss | 0.00468     |
# |    value_loss           | 18.2        |
# -----------------------------------------
# Episode: 1065,TP: 50.0, FP: 0.0, R: -3.090909427059998
# TPR_h: 98.48, FPR_h: 3.99
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.99e+03   |
# |    ep_rew_mean          | 1.1e+03    |
# | time/                   |            |
# |    fps                  | 559        |
# |    iterations           | 36         |
# |    time_elapsed         | 131        |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.03406253 |
# |    clip_fraction        | 0.071      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0781    |
# |    explained_variance   | 0.975      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.98       |
# |    n_updates            | 5340       |
# |    policy_gradient_loss | 0.0289     |
# |    value_loss           | 5.93       |
# ----------------------------------------
# Episode: 1066,TP: 50.0, FP: 0.0, R: -16.261118494900018
# TPR_h: 91.64, FPR_h: 5.6
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 1.11e+03    |
# | time/                   |             |
# |    fps                  | 559         |
# |    iterations           | 37          |
# |    time_elapsed         | 135         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.013499185 |
# |    clip_fraction        | 0.0251      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0392     |
# |    explained_variance   | 0.98        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.65        |
# |    n_updates            | 5350        |
# |    policy_gradient_loss | 0.0026      |
# |    value_loss           | 4.7         |
# -----------------------------------------
# Episode: 1067,TP: 50.0, FP: 0.0, R: -14.255389063400003
# TPR_h: 92.59, FPR_h: 2.85
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 1.11e+03    |
# | time/                   |             |
# |    fps                  | 559         |
# |    iterations           | 38          |
# |    time_elapsed         | 139         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.018807782 |
# |    clip_fraction        | 0.0486      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0657     |
# |    explained_variance   | 0.972       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.94        |
# |    n_updates            | 5360        |
# |    policy_gradient_loss | -0.00103    |
# |    value_loss           | 5.5         |
# -----------------------------------------
# Episode: 1068,TP: 50.0, FP: 0.0, R: -4.068876147609984
# TPR_h: 98.1, FPR_h: 6.08
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.99e+03     |
# |    ep_rew_mean          | 1.12e+03     |
# | time/                   |              |
# |    fps                  | 559          |
# |    iterations           | 39           |
# |    time_elapsed         | 142          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0025878658 |
# |    clip_fraction        | 0.0241       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0457      |
# |    explained_variance   | 0.949        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.8          |
# |    n_updates            | 5370         |
# |    policy_gradient_loss | 0.00187      |
# |    value_loss           | 7.32         |
# ------------------------------------------
# Episode: 1069,TP: 0.0, FP: 0.0, R: -55.37263721179
# TPR_h: 66.76, FPR_h: 1.99
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.99e+03   |
# |    ep_rew_mean          | 1.11e+03   |
# | time/                   |            |
# |    fps                  | 559        |
# |    iterations           | 40         |
# |    time_elapsed         | 146        |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.08294608 |
# |    clip_fraction        | 0.0538     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0665    |
# |    explained_variance   | 0.958      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.41       |
# |    n_updates            | 5380       |
# |    policy_gradient_loss | -0.00289   |
# |    value_loss           | 6.08       |
# ----------------------------------------
# Episode: 1070,TP: 50.0, FP: 0.0, R: -98.19435506114002
# TPR_h: 13.3, FPR_h: 2.37
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 1.08e+03    |
# | time/                   |             |
# |    fps                  | 559         |
# |    iterations           | 41          |
# |    time_elapsed         | 150         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.096144676 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.131      |
# |    explained_variance   | 0.888       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.6         |
# |    n_updates            | 5390        |
# |    policy_gradient_loss | 0.00838     |
# |    value_loss           | 19          |
# -----------------------------------------
# Episode: 1071,TP: 50.0, FP: 0.0, R: -95.47468304515
# TPR_h: 21.08, FPR_h: 1.33
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 1.06e+03    |
# | time/                   |             |
# |    fps                  | 558         |
# |    iterations           | 42          |
# |    time_elapsed         | 153         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.004465243 |
# |    clip_fraction        | 0.0516      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0878     |
# |    explained_variance   | 0.847       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.16        |
# |    n_updates            | 5400        |
# |    policy_gradient_loss | 0.00462     |
# |    value_loss           | 39.1        |
# -----------------------------------------
# Episode: 1072,TP: 50.0, FP: 0.0, R: -57.97428970985001
# TPR_h: 64.77, FPR_h: 1.42
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.99e+03     |
# |    ep_rew_mean          | 1.06e+03     |
# | time/                   |              |
# |    fps                  | 558          |
# |    iterations           | 43           |
# |    time_elapsed         | 157          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0036555927 |
# |    clip_fraction        | 0.036        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.104       |
# |    explained_variance   | 0.778        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.7          |
# |    n_updates            | 5410         |
# |    policy_gradient_loss | 0.0017       |
# |    value_loss           | 42.8         |
# ------------------------------------------
# Episode: 1073,TP: 50.0, FP: 0.0, R: -3.335049255739989
# TPR_h: 98.48, FPR_h: 6.17
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.99e+03   |
# |    ep_rew_mean          | 1.06e+03   |
# | time/                   |            |
# |    fps                  | 558        |
# |    iterations           | 44         |
# |    time_elapsed         | 161        |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.14034875 |
# |    clip_fraction        | 0.169      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.128     |
# |    explained_variance   | 0.844      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 6.02       |
# |    n_updates            | 5420       |
# |    policy_gradient_loss | 0.0124     |
# |    value_loss           | 18.4       |
# ----------------------------------------
# Episode: 1074,TP: 0.0, FP: 0.0, R: -70.33525463590001
# TPR_h: 54.7, FPR_h: 5.7
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 1.05e+03    |
# | time/                   |             |
# |    fps                  | 558         |
# |    iterations           | 45          |
# |    time_elapsed         | 164         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.008985084 |
# |    clip_fraction        | 0.0444      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0731     |
# |    explained_variance   | 0.684       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.52        |
# |    n_updates            | 5430        |
# |    policy_gradient_loss | 0.0031      |
# |    value_loss           | 7.65        |
# -----------------------------------------
# Episode: 1075,TP: 50.0, FP: 0.0, R: -47.191698165690006
# TPR_h: 72.93, FPR_h: 6.65
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 1.05e+03    |
# | time/                   |             |
# |    fps                  | 558         |
# |    iterations           | 46          |
# |    time_elapsed         | 168         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.021416435 |
# |    clip_fraction        | 0.089       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.12       |
# |    explained_variance   | 0.713       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.9        |
# |    n_updates            | 5440        |
# |    policy_gradient_loss | 0.004       |
# |    value_loss           | 27.9        |
# -----------------------------------------
# Episode: 1076,TP: 50.0, FP: 0.0, R: -30.25758888899
# TPR_h: 83.48, FPR_h: 1.9
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 1.99e+03 |
# |    ep_rew_mean          | 1.05e+03 |
# | time/                   |          |
# |    fps                  | 559      |
# |    iterations           | 47       |
# |    time_elapsed         | 172      |
# |    total_timesteps      | 96256    |
# | train/                  |          |
# |    approx_kl            | 0.462439 |
# |    clip_fraction        | 0.152    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.101   |
# |    explained_variance   | 0.768    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 6.3      |
# |    n_updates            | 5450     |
# |    policy_gradient_loss | 0.0831   |
# |    value_loss           | 18.5     |
# --------------------------------------
# Episode: 1077,TP: 0.0, FP: 0.0, R: -99.30410691435
# TPR_h: 7.88, FPR_h: 1.52
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 1.03e+03    |
# | time/                   |             |
# |    fps                  | 558         |
# |    iterations           | 48          |
# |    time_elapsed         | 175         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.020191047 |
# |    clip_fraction        | 0.0538      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.101      |
# |    explained_variance   | 0.469       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.1        |
# |    n_updates            | 5460        |
# |    policy_gradient_loss | 0.000857    |
# |    value_loss           | 19.8        |
# -----------------------------------------
# Episode: 1078,TP: 0.0, FP: 0.0, R: -35.54809996129002
# TPR_h: 80.25, FPR_h: 1.99
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.99e+03     |
# |    ep_rew_mean          | 1.03e+03     |
# | time/                   |              |
# |    fps                  | 558          |
# |    iterations           | 49           |
# |    time_elapsed         | 179          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0059751924 |
# |    clip_fraction        | 0.0229       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0599      |
# |    explained_variance   | 0.573        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.16         |
# |    n_updates            | 5470         |
# |    policy_gradient_loss | 0.000938     |
# |    value_loss           | 44.6         |
# ------------------------------------------
# Episode: 1079,TP: 50.0, FP: 0.0, R: -69.48856382706
# TPR_h: 55.18, FPR_h: 1.71
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 1.02e+03    |
# | time/                   |             |
# |    fps                  | 558         |
# |    iterations           | 50          |
# |    time_elapsed         | 183         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.059107065 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0867     |
# |    explained_variance   | 0.757       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.71        |
# |    n_updates            | 5480        |
# |    policy_gradient_loss | 0.0482      |
# |    value_loss           | 13          |
# -----------------------------------------
# Episode: 1080,TP: 50.0, FP: 0.0, R: -6.509444232510007
# TPR_h: 96.68, FPR_h: 2.56
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.99e+03   |
# |    ep_rew_mean          | 1.03e+03   |
# | time/                   |            |
# |    fps                  | 558        |
# |    iterations           | 51         |
# |    time_elapsed         | 186        |
# ...
# TPR_h: 95.63, FPR_h: 6.55
# Episode: 1981,TP: 0.0, FP: 0.0, R: -5.619808522089983
# TPR_h: 97.34, FPR_h: 6.55
# Episode: 1982,TP: 50.0, FP: 0.0, R: -8.505125114410006
# TPR_h: 96.3, FPR_h: 11.02
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 1.19e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 593      |
# |    time_elapsed     | 1476     |
# |    total_timesteps  | 875600   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.216    |
# |    n_updates        | 473849   |
# ----------------------------------
# Episode: 1983,TP: 50.0, FP: 0.0, R: -61.47097513996001
# TPR_h: 62.39, FPR_h: 6.74
# Episode: 1984,TP: 50.0, FP: 0.0, R: -8.51022993366
# TPR_h: 96.2, FPR_h: 10.26
# Episode: 1985,TP: 50.0, FP: 0.0, R: -15.665196798890022
# TPR_h: 92.31, FPR_h: 9.4
# Episode: 1986,TP: 50.0, FP: 0.0, R: -11.467921597560007
# TPR_h: 94.97, FPR_h: 12.63
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 1.18e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 593      |
# |    time_elapsed     | 1489     |
# |    total_timesteps  | 883560   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.38     |
# |    n_updates        | 475839   |
# ----------------------------------
# Episode: 1987,TP: 50.0, FP: 0.0, R: -8.75726614121001
# TPR_h: 95.63, FPR_h: 5.32
# Episode: 1988,TP: 50.0, FP: 0.0, R: -43.519878482110016
# TPR_h: 75.31, FPR_h: 5.51
# Episode: 1989,TP: 50.0, FP: 0.0, R: -6.753006553139996
# TPR_h: 96.87, FPR_h: 7.88
# Episode: 1990,TP: 50.0, FP: 0.0, R: -15.294701256189997
# TPR_h: 92.5, FPR_h: 9.31
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 1.19e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 593      |
# |    time_elapsed     | 1503     |
# |    total_timesteps  | 891520   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.219    |
# |    n_updates        | 477829   |
# ----------------------------------
# Episode: 1991,TP: 50.0, FP: 0.0, R: -14.402260068860002
# TPR_h: 92.78, FPR_h: 7.31
# Episode: 1992,TP: 50.0, FP: 0.0, R: -64.39337120146001
# TPR_h: 59.73, FPR_h: 3.99
# Episode: 1993,TP: 50.0, FP: 0.0, R: -17.65002563716
# TPR_h: 90.79, FPR_h: 3.99
# Episode: 1994,TP: 50.0, FP: 0.0, R: -29.25598434769
# TPR_h: 84.33, FPR_h: 6.55
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 1.18e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 592      |
# |    time_elapsed     | 1516     |
# |    total_timesteps  | 899480   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.244    |
# |    n_updates        | 479819   |
# ----------------------------------
# Episode: 1995,TP: 50.0, FP: 0.0, R: -38.45922941794002
# TPR_h: 79.2, FPR_h: 10.83
# Episode: 1996,TP: 50.0, FP: 0.0, R: -16.991806814410026
# TPR_h: 91.26, FPR_h: 5.89
# Episode: 1997,TP: 50.0, FP: 0.0, R: -19.704540011760002
# TPR_h: 89.84, FPR_h: 6.84
# Episode: 1998,TP: 50.0, FP: 0.0, R: -12.207841994139997
# TPR_h: 94.02, FPR_h: 7.98
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 1.18e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 592      |
# |    time_elapsed     | 1530     |
# |    total_timesteps  | 907440   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.252    |
# |    n_updates        | 481809   |
# ----------------------------------
# Episode: 1999,TP: 50.0, FP: 0.0, R: -8.86577605155999
# TPR_h: 95.54, FPR_h: 4.65
# Episode: 2000,TP: 50.0, FP: 0.0, R: -36.17141285809002
# TPR_h: 80.25, FPR_h: 7.79
# Episode: 2001,TP: 50.0, FP: 0.0, R: -44.23359044646
# TPR_h: 75.02, FPR_h: 7.5
# Episode: 2002,TP: 50.0, FP: 0.0, R: -67.24457480484
# TPR_h: 57.74, FPR_h: 7.88
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 1.17e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 592      |
# |    time_elapsed     | 1544     |
# |    total_timesteps  | 915400   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.352    |
# |    n_updates        | 483799   |
# ----------------------------------
# Episode: 2003,TP: 50.0, FP: 0.0, R: -7.551567093610004
# TPR_h: 96.3, FPR_h: 5.89
# Episode: 2004,TP: 0.0, FP: 0.0, R: -24.31406379104
# TPR_h: 87.46, FPR_h: 9.12
# Episode: 2005,TP: 0.0, FP: 0.0, R: -29.927545474100015
# TPR_h: 83.86, FPR_h: 5.6
# Episode: 2006,TP: 50.0, FP: 0.0, R: -10.466161782739986
# TPR_h: 95.06, FPR_h: 9.21
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 1.17e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 592      |
# |    time_elapsed     | 1558     |
# |    total_timesteps  | 923360   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.358    |
# |    n_updates        | 485789   |
# ----------------------------------
# Episode: 2007,TP: 50.0, FP: 0.0, R: -23.934166595689984
# TPR_h: 87.84, FPR_h: 10.45
# Episode: 2008,TP: 50.0, FP: 0.0, R: -8.86577605155999
# TPR_h: 95.54, FPR_h: 4.65
# Episode: 2009,TP: 50.0, FP: 0.0, R: -10.481947240060007
# TPR_h: 94.68, FPR_h: 4.56
# Episode: 2010,TP: 50.0, FP: 0.0, R: -44.62821939014001
# TPR_h: 74.64, FPR_h: 6.36
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 1.17e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 592      |
# |    time_elapsed     | 1572     |
# |    total_timesteps  | 931320   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.244    |
# |    n_updates        | 487779   |
# ----------------------------------
# Episode: 2011,TP: 50.0, FP: 0.0, R: -8.108614159150036
# TPR_h: 96.11, FPR_h: 7.22
# Episode: 2012,TP: 50.0, FP: 0.0, R: -6.357767518089999
# TPR_h: 96.96, FPR_h: 6.55
# Episode: 2013,TP: 50.0, FP: 0.0, R: -6.672680106139992
# TPR_h: 96.77, FPR_h: 6.17
# Episode: 2014,TP: 50.0, FP: 0.0, R: -92.27905090994001
# TPR_h: 27.83, FPR_h: 3.32
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 1.17e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 592      |
# |    time_elapsed     | 1586     |
# |    total_timesteps  | 939280   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.384    |
# |    n_updates        | 489769   |
# ----------------------------------
# Episode: 2015,TP: 50.0, FP: 0.0, R: -22.339552634750007
# TPR_h: 88.7, FPR_h: 10.07
# Episode: 2016,TP: 50.0, FP: 0.0, R: -14.865981048500002
# TPR_h: 92.97, FPR_h: 11.3
# Episode: 2017,TP: 50.0, FP: 0.0, R: -41.67586850276001
# TPR_h: 76.45, FPR_h: 4.46
# Episode: 2018,TP: 50.0, FP: 0.0, R: -24.038196086590006
# TPR_h: 87.37, FPR_h: 6.55
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 1.16e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 592      |
# |    time_elapsed     | 1599     |
# |    total_timesteps  | 947240   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.358    |
# |    n_updates        | 491759   |
# ----------------------------------
# Episode: 2019,TP: 50.0, FP: 0.0, R: -15.2253188311
# TPR_h: 92.21, FPR_h: 5.7
# Episode: 2020,TP: 50.0, FP: 0.0, R: -59.2874106664
# TPR_h: 64.01, FPR_h: 5.7
# Episode: 2021,TP: 50.0, FP: 0.0, R: -11.990079147710006
# TPR_h: 94.21, FPR_h: 8.74
# Episode: 2022,TP: 50.0, FP: 0.0, R: -6.403317529610007
# TPR_h: 96.87, FPR_h: 5.51
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 1.17e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 592      |
# |    time_elapsed     | 1613     |
# |    total_timesteps  | 955200   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.125    |
# |    n_updates        | 493749   |
# ----------------------------------
# Episode: 2023,TP: 0.0, FP: 0.0, R: -48.79158192835003
# TPR_h: 71.89, FPR_h: 7.22
# Episode: 2024,TP: 50.0, FP: 0.0, R: -35.56876258066002
# TPR_h: 80.91, FPR_h: 10.16
# Episode: 2025,TP: 50.0, FP: 0.0, R: -28.05158155084001
# TPR_h: 85.19, FPR_h: 8.07
# Episode: 2026,TP: 0.0, FP: 0.0, R: -44.46386952288999
# TPR_h: 75.12, FPR_h: 9.5
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 1.15e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 592      |
# |    time_elapsed     | 1626     |
# |    total_timesteps  | 963160   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.441    |
# |    n_updates        | 495739   |
# ----------------------------------
# Episode: 2027,TP: 0.0, FP: 0.0, R: -31.330824159610003
# TPR_h: 83.0, FPR_h: 5.41
# Episode: 2028,TP: 50.0, FP: 0.0, R: -6.107678192510008
# TPR_h: 97.06, FPR_h: 6.08
# Episode: 2029,TP: 50.0, FP: 0.0, R: -12.975663986740017
# TPR_h: 93.92, FPR_h: 10.83
# Episode: 2030,TP: 50.0, FP: 0.0, R: -27.43702188041
# TPR_h: 85.57, FPR_h: 8.26
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 1.15e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 591      |
# |    time_elapsed     | 1641     |
# |    total_timesteps  | 971120   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.163    |
# |    n_updates        | 497729   |
# ----------------------------------
# Episode: 2031,TP: 50.0, FP: 0.0, R: -12.720699274810018
# TPR_h: 93.54, FPR_h: 5.41
# Episode: 2032,TP: 50.0, FP: 0.0, R: -5.820480945610001
# TPR_h: 97.44, FPR_h: 8.83
# Episode: 2033,TP: 50.0, FP: 0.0, R: -21.787057856510003
# TPR_h: 88.6, FPR_h: 5.98
# Episode: 2034,TP: 50.0, FP: 0.0, R: -25.526513278099998
# TPR_h: 86.7, FPR_h: 8.55
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 1.16e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 591      |
# |    time_elapsed     | 1655     |
# |    total_timesteps  | 979080   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.263    |
# |    n_updates        | 499719   |
# ----------------------------------
# Episode: 2035,TP: 50.0, FP: 0.0, R: -66.15793858219
# TPR_h: 58.31, FPR_h: 4.84
# Episode: 2036,TP: 50.0, FP: 0.0, R: -48.63991575835
# TPR_h: 71.98, FPR_h: 7.12
# Episode: 2037,TP: 50.0, FP: 0.0, R: -7.793631894190027
# TPR_h: 96.11, FPR_h: 4.84
# Episode: 2038,TP: 50.0, FP: 0.0, R: -34.76021341459
# TPR_h: 81.1, FPR_h: 7.6
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 1.14e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 591      |
# |    time_elapsed     | 1668     |
# |    total_timesteps  | 987040   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.183    |
# |    n_updates        | 501709   |
# ----------------------------------
# Episode: 2039,TP: 50.0, FP: 0.0, R: -34.77619104659
# TPR_h: 81.1, FPR_h: 7.69
# Episode: 2040,TP: 50.0, FP: 0.0, R: -13.932147148660007
# TPR_h: 93.35, FPR_h: 10.35
# Episode: 2041,TP: 50.0, FP: 0.0, R: -10.285815115850001
# TPR_h: 95.25, FPR_h: 10.07
# Episode: 2042,TP: 50.0, FP: 0.0, R: -23.434405541150014
# TPR_h: 87.56, FPR_h: 4.27
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 1.15e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 591      |
# |    time_elapsed     | 1682     |
# |    total_timesteps  | 995000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.419    |
# |    n_updates        | 503699   |
# ----------------------------------
# Episode: 2043,TP: 50.0, FP: 0.0, R: -14.585242310639998
# TPR_h: 92.59, FPR_h: 6.17
# Episode: 2044,TP: 50.0, FP: 0.0, R: -8.111856716910012
# TPR_h: 96.01, FPR_h: 5.98
# Episode: 2045,TP: 50.0, FP: 0.0, R: -16.273018198100004
# TPR_h: 92.21, FPR_h: 11.3
# Episode: 2046,TP: 50.0, FP: 0.0, R: -11.298254258600025
# TPR_h: 94.87, FPR_h: 11.3
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 1.15e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 504      |
# |    fps              | 591      |
# |    time_elapsed     | 1696     |
# |    total_timesteps  | 1002960  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.393    |
# |    n_updates        | 505689   |
# ----------------------------------
# Episode: 2047,TP: 50.0, FP: 0.0, R: -6.541903358089996
# TPR_h: 96.87, FPR_h: 6.55
# Episode: 2048,TP: 50.0, FP: 0.0, R: -10.647700338009997
# TPR_h: 95.25, FPR_h: 11.59
# Episode: 2049,TP: 50.0, FP: 0.0, R: -6.32047470336002
# TPR_h: 97.06, FPR_h: 7.5
# Episode: 2050,TP: 50.0, FP: 0.0, R: -47.74342365385
# TPR_h: 72.36, FPR_h: 4.37
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 1.15e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 508      |
# |    fps              | 591      |
# |    time_elapsed     | 1710     |
# |    total_timesteps  | 1010920  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.129    |
# |    n_updates        | 507679   |
# ----------------------------------
# Episode: 2051,TP: 50.0, FP: 0.0, R: -34.488704179959996
# TPR_h: 81.58, FPR_h: 10.16
# Episode: 2052,TP: 50.0, FP: 0.0, R: -15.200830172340007
# TPR_h: 92.4, FPR_h: 7.88
# Episode: 2053,TP: 50.0, FP: 0.0, R: -12.639885819839973
# TPR_h: 93.64, FPR_h: 6.17
# Episode: 2054,TP: 50.0, FP: 0.0, R: -14.276650992189984
# TPR_h: 93.07, FPR_h: 9.5
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 1.15e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 512      |
# |    fps              | 591      |
# |    time_elapsed     | 1723     |
# |    total_timesteps  | 1018880  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.196    |
# |    n_updates        | 509669   |
# ----------------------------------

# %%
def my_evaluate_model(model, env, num_episodes=50,model_name = 'ppo'):
    tpr_hist = []
    fpr_hist = []
    rewards = []

    for episode in range(num_episodes):
        obs = env.reset()
        obs = obs[0]
        done = False
        total_reward = 0
        tpr_episode = []
        fpr_episode = []
        ep = 0

        while not done:
            action, _ = model.predict(obs, deterministic=True)
            # bs, reward, terminated, truncated, info 
            obs, reward, done, truncated, info = env.step(action)
            total_reward += reward
            if not np.isnan(info['tp_rate']):
                tpr_episode.append(info['tp_rate'])
                fpr_episode.append(info['fp_rate'])
                # print(info)
                done = True
    
        if model_name == 'dqn':
            model.train(gradient_steps=10)
        else:
            model.train()
        tpr_hist.append(np.mean(tpr_episode))
        fpr_hist.append(np.mean(fpr_episode))
        rewards.append(total_reward)

    return tpr_hist, fpr_hist, rewards

snr = -2.5
data = c_states[snr]
# env = DummyVecEnv([lambda: FrequencyDetectionEnv(data)])
eval_env = TEST_FrequencyDetectionEnv(data)
num_episodes = 100

# Evaluate both models
tpr_ppo, fpr_ppo, rewards_ppo = my_evaluate_model(model_ppo, eval_env,num_episodes=num_episodes)
tpr_dqn, fpr_dqn, rewards_dqn = my_evaluate_model(model_dqn, eval_env,model_name='dqn',num_episodes=num_episodes)

episodes = range(1, num_episodes+1)

plt.figure(figsize=(12, 8))

# Plot TPR
plt.subplot(3, 1, 1)
plt.plot(episodes, tpr_ppo, label='PPO')
plt.plot(episodes, tpr_dqn, label='DQN')
plt.ylabel('TPR_h')
plt.legend()

# Plot FPR
plt.subplot(3, 1, 2)
plt.plot(episodes, fpr_ppo, label='PPO')
plt.plot(episodes, fpr_dqn, label='DQN')
plt.ylabel('FPR_h')
plt.legend()

# Plot Rewards
plt.subplot(3, 1, 3)
plt.plot(episodes, rewards_ppo, label='PPO')
plt.plot(episodes, rewards_dqn, label='DQN')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Episode: 1,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 78.54, FPR_h: 12.63
# Episode: 2,TP: 0.0, FP: 0.0, R: 0
# TPR_h: 91.26, FPR_h: 9.31
# Episode: 3,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 85.0, FPR_h: 8.26
# Episode: 4,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 96.68, FPR_h: 10.83
# Episode: 5,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 77.11, FPR_h: 10.16
# Episode: 6,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 95.44, FPR_h: 11.3
# Episode: 7,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.91, FPR_h: 4.84
# Episode: 8,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 83.29, FPR_h: 12.35
# Episode: 9,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 92.97, FPR_h: 7.5
# Episode: 10,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 98.67, FPR_h: 16.81
# Episode: 11,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 98.58, FPR_h: 9.59
# Episode: 12,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 96.49, FPR_h: 8.55
# Episode: 13,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 98.01, FPR_h: 9.4
# Episode: 14,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 93.07, FPR_h: 7.88
# Episode: 15,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 95.16, FPR_h: 15.38
# Episode: 16,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 85.0, FPR_h: 6.65
# Episode: 17,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.62, FPR_h: 5.6
# Episode: 18,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 94.3, FPR_h: 8.07
# Episode: 19,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.34, FPR_h: 13.11
# Episode: 20,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 98.29, FPR_h: 9.12
# Episode: 21,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 89.46, FPR_h: 9.21
# Episode: 22,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 97.15, FPR_h: 12.06
# Episode: 23,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.43, FPR_h: 17.0
# Episode: 24,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 95.82, FPR_h: 7.6
# Episode: 25,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.15, FPR_h: 6.36
# Episode: 26,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 54.42, FPR_h: 7.88
# Episode: 27,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.15, FPR_h: 7.31
# Episode: 28,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.43, FPR_h: 10.16
# Episode: 29,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 90.22, FPR_h: 12.44
# Episode: 30,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.91, FPR_h: 10.92
# Episode: 31,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 96.3, FPR_h: 9.59
# Episode: 32,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 78.54, FPR_h: 9.12
# Episode: 33,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.91, FPR_h: 10.92
# Episode: 34,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.91, FPR_h: 17.57
# Episode: 35,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 100.0, FPR_h: 10.35
# Episode: 36,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.34, FPR_h: 11.78
# Episode: 37,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 93.92, FPR_h: 9.59
# Episode: 38,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 98.86, FPR_h: 10.92
# Episode: 39,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.91, FPR_h: 7.98
# Episode: 40,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 80.44, FPR_h: 15.29
# Episode: 41,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.34, FPR_h: 14.15
# Episode: 42,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 96.87, FPR_h: 4.27
# Episode: 43,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.53, FPR_h: 11.87
# Episode: 44,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 96.39, FPR_h: 11.21
# Episode: 45,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.62, FPR_h: 10.35
# Episode: 46,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.34, FPR_h: 9.02
# Episode: 47,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 100.0, FPR_h: 8.55
# Episode: 48,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.05, FPR_h: 10.83
# Episode: 49,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 100.0, FPR_h: 14.43
# Episode: 50,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 96.49, FPR_h: 12.73
# Episode: 51,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 86.89, FPR_h: 16.24
# Episode: 52,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 95.06, FPR_h: 8.74
# Episode: 53,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 98.29, FPR_h: 9.59
# Episode: 54,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.15, FPR_h: 8.55
# Episode: 55,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 95.25, FPR_h: 15.67
# Episode: 56,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.53, FPR_h: 13.3
# Episode: 57,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 97.91, FPR_h: 14.53
# Episode: 58,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 97.15, FPR_h: 10.26
# Episode: 59,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 96.2, FPR_h: 12.16
# Episode: 60,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.15, FPR_h: 14.34
# Episode: 61,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 79.87, FPR_h: 17.38
# Episode: 62,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 97.91, FPR_h: 13.3
# Episode: 63,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 77.11, FPR_h: 9.12
# Episode: 64,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 72.08, FPR_h: 12.35
# Episode: 65,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 93.07, FPR_h: 10.26
# Episode: 66,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.15, FPR_h: 9.97
# Episode: 67,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 96.96, FPR_h: 13.96
# Episode: 68,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 96.39, FPR_h: 13.39
# Episode: 69,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 78.44, FPR_h: 15.29
# Episode: 70,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 93.35, FPR_h: 14.15
# Episode: 71,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.81, FPR_h: 15.38
# Episode: 72,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 97.91, FPR_h: 14.91
# Episode: 73,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 98.96, FPR_h: 12.54
# Episode: 74,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 98.2, FPR_h: 11.68
# Episode: 75,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 98.86, FPR_h: 10.26
# Episode: 76,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 97.63, FPR_h: 9.88
# Episode: 77,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 77.02, FPR_h: 6.74
# Episode: 78,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.72, FPR_h: 12.92
# Episode: 79,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 96.49, FPR_h: 9.21
# Episode: 80,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.05, FPR_h: 10.16
# Episode: 81,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 78.82, FPR_h: 20.8
# Episode: 82,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 98.86, FPR_h: 15.1
# Episode: 83,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 63.91, FPR_h: 13.87
# Episode: 84,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.62, FPR_h: 16.14
# Episode: 85,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 100.0, FPR_h: 13.39
# Episode: 86,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 98.2, FPR_h: 11.3
# Episode: 87,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 93.16, FPR_h: 9.88
# Episode: 88,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 94.02, FPR_h: 11.97
# Episode: 89,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 98.86, FPR_h: 11.02
# Episode: 90,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.24, FPR_h: 9.02
# Episode: 91,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.72, FPR_h: 14.25
# Episode: 92,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.72, FPR_h: 15.19
# Episode: 93,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.43, FPR_h: 6.36
# Episode: 94,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 100.0, FPR_h: 11.02
# Episode: 95,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.53, FPR_h: 7.88
# Episode: 96,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.81, FPR_h: 13.01
# Episode: 97,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 81.67, FPR_h: 8.26
# Episode: 98,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 98.77, FPR_h: 12.54
# Episode: 99,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 96.3, FPR_h: 10.35
# Episode: 100,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 97.72, FPR_h: 11.68
# Episode: 101,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 74.26, FPR_h: 6.74
# Episode: 102,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.91, FPR_h: 12.16
# Episode: 103,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 74.55, FPR_h: 5.22
# Episode: 104,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 80.34, FPR_h: 7.6
# Episode: 105,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 98.67, FPR_h: 4.84
# Episode: 106,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 98.39, FPR_h: 1.99
# Episode: 107,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 80.91, FPR_h: 5.41
# Episode: 108,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.72, FPR_h: 1.71
# Episode: 109,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 98.77, FPR_h: 4.94
# Episode: 110,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.34, FPR_h: 3.23
# Episode: 111,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 98.58, FPR_h: 5.03
# Episode: 112,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 100.0, FPR_h: 5.98
# Episode: 113,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 79.3, FPR_h: 6.55
# Episode: 114,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.91, FPR_h: 1.14
# Episode: 115,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 98.67, FPR_h: 5.98
# Episode: 116,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 80.25, FPR_h: 3.51
# Episode: 117,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.91, FPR_h: 8.17
# Episode: 118,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.91, FPR_h: 5.22
# Episode: 119,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 96.58, FPR_h: 5.13
# Episode: 120,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 90.88, FPR_h: 4.75
# Episode: 121,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.24, FPR_h: 6.93
# Episode: 122,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 87.27, FPR_h: 8.36
# Episode: 123,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 96.3, FPR_h: 4.46
# Episode: 124,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.15, FPR_h: 8.36
# Episode: 125,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 92.12, FPR_h: 4.08
# Episode: 126,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 81.86, FPR_h: 3.89
# Episode: 127,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 84.14, FPR_h: 1.23
# Episode: 128,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 93.83, FPR_h: 5.89
# Episode: 129,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.34, FPR_h: 12.82
# Episode: 130,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 97.44, FPR_h: 4.08
# Episode: 131,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 97.72, FPR_h: 6.65
# Episode: 132,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 98.29, FPR_h: 3.99
# Episode: 133,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.34, FPR_h: 6.93
# Episode: 134,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.72, FPR_h: 3.99
# Episode: 135,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 98.48, FPR_h: 7.12
# Episode: 136,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.24, FPR_h: 4.75
# Episode: 137,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 93.35, FPR_h: 7.41
# Episode: 138,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.34, FPR_h: 4.56
# Episode: 139,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 84.33, FPR_h: 5.7
# Episode: 140,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 83.1, FPR_h: 1.99
# Episode: 141,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.62, FPR_h: 5.03
# Episode: 142,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 77.78, FPR_h: 3.04
# Episode: 143,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 100.0, FPR_h: 7.03
# Episode: 144,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 91.36, FPR_h: 6.74
# Episode: 145,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 100.0, FPR_h: 6.46
# Episode: 146,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.91, FPR_h: 4.46
# Episode: 147,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 81.1, FPR_h: 9.02
# Episode: 148,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 98.77, FPR_h: 7.88
# Episode: 149,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 100.0, FPR_h: 1.8
# Episode: 150,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 55.08, FPR_h: 5.32
# Episode: 151,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 92.59, FPR_h: 6.55
# Episode: 152,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.53, FPR_h: 9.02
# Episode: 153,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 100.0, FPR_h: 4.27
# Episode: 154,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 100.0, FPR_h: 3.89
# Episode: 155,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 95.35, FPR_h: 5.41
# Episode: 156,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.72, FPR_h: 8.83
# Episode: 157,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 100.0, FPR_h: 6.27
# Episode: 158,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 93.83, FPR_h: 5.13
# Episode: 159,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 97.34, FPR_h: 5.79
# Episode: 160,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.72, FPR_h: 1.99
# Episode: 161,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 79.87, FPR_h: 2.47
# Episode: 162,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 100.0, FPR_h: 2.94
# Episode: 163,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 98.39, FPR_h: 6.27
# Episode: 164,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.34, FPR_h: 12.16
# Episode: 165,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.72, FPR_h: 6.74
# Episode: 166,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 100.0, FPR_h: 3.32
# Episode: 167,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.72, FPR_h: 7.31
# Episode: 168,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 80.91, FPR_h: 6.46
# Episode: 169,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 98.01, FPR_h: 6.17
# Episode: 170,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 97.25, FPR_h: 8.17
# Episode: 171,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 97.06, FPR_h: 7.22
# Episode: 172,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 98.29, FPR_h: 6.46
# Episode: 173,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 77.3, FPR_h: 5.22
# Episode: 174,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 97.63, FPR_h: 11.21
# Episode: 175,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 98.1, FPR_h: 5.89
# Episode: 176,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 89.08, FPR_h: 6.84
# Episode: 177,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 98.86, FPR_h: 6.36
# Episode: 178,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.24, FPR_h: 9.59
# Episode: 179,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 98.2, FPR_h: 2.28
# Episode: 180,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.34, FPR_h: 4.94
# Episode: 181,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 97.82, FPR_h: 4.27
# Episode: 182,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 98.96, FPR_h: 2.66
# Episode: 183,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 84.05, FPR_h: 3.23
# Episode: 184,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 100.0, FPR_h: 5.41
# Episode: 185,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 98.86, FPR_h: 2.75
# Episode: 186,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 96.01, FPR_h: 7.41
# Episode: 187,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 73.6, FPR_h: 4.27
# Episode: 188,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 100.0, FPR_h: 2.66
# Episode: 189,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 98.77, FPR_h: 9.31
# Episode: 190,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 93.54, FPR_h: 3.42
# Episode: 191,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.91, FPR_h: 7.79
# Episode: 192,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 97.44, FPR_h: 0.85
# Episode: 193,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.43, FPR_h: 1.9
# Episode: 194,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.72, FPR_h: 3.23
# Episode: 195,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.53, FPR_h: 5.32
# Episode: 196,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.91, FPR_h: 6.08
# Episode: 197,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 98.1, FPR_h: 5.6
# Episode: 198,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.62, FPR_h: 4.94
# Episode: 199,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.43, FPR_h: 6.27
# Episode: 200,TP: 50.0, FP: 0.0, R: 0
# TPR_h: 99.72, FPR_h: 2.94

# %%
model_ppo.save('ppo_snr0-5.zip')
model_dqn.save('dqn_snr0-5.zip')

# %%
with open('c_states_dict_acer_2.pkl', 'rb') as f:
    c_states_test = pickle.load(f)

c_states_test.keys()
# Out:
# dict_keys([5, 0, -5, -10, -15, -20, -25])

# %%
# for 
snr = -2.5
for snr in [5, 0, -5, -10, -15, -20, -25]:
    data = c_states_test[snr]
    # env = DummyVecEnv([lambda: FrequencyDetectionEnv(data)])
    eval_env = TEST_FrequencyDetectionEnv(data)
    num_episodes = 100

    # Evaluate both models
    tpr_ppo, fpr_ppo, rewards_ppo = my_evaluate_model(model_ppo, eval_env,num_episodes=num_episodes)
    tpr_dqn, fpr_dqn, rewards_dqn = my_evaluate_model(model_dqn, eval_env,model_name='dqn',num_episodes=num_episodes)

    episodes = range(1, num_episodes+1)

    plt.figure(figsize=(12, 8))

    # Plot TPR
    plt.title('snr='+str(snr))
    plt.subplot(3, 1, 1)
    plt.plot(episodes, tpr_ppo, label='PPO')
    plt.plot(episodes, tpr_dqn, label='DQN')
    plt.ylabel('TPR_h')
    plt.legend()

    # Plot FPR
    plt.subplot(3, 1, 2)
    plt.plot(episodes, fpr_ppo, label='PPO')
    plt.plot(episodes, fpr_dqn, label='DQN')
    plt.ylabel('FPR_h')
    plt.legend()

    # Plot Rewards
    plt.subplot(3, 1, 3)
    plt.plot(episodes, rewards_ppo, label='PPO')
    plt.plot(episodes, rewards_dqn, label='DQN')
    plt.xlabel('Episode')
    plt.ylabel('Reward')
    plt.legend()

    # plt.tight_layout()
    plt.show()
